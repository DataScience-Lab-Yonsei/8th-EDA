# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
from collections import Counter

# %%
app = pd.read_csv('../archive_googleplaystore/googleplaystore_preprocessed.csv')
review = pd.read_csv('../archive_googleplaystore/googleplaystore_user_reviews_preprocessed.csv')

# %%
data1 = app
data2 = review

# %%
app.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews        Size    Installs  Price Content Rating  \
# 0      159  19000000.0     10000.0    0.0       Everyone
# 1      967  14000000.0    500000.0    0.0       Everyone
# 2    87510   8700000.0   5000000.0    0.0       Everyone
# 3   215644  25000000.0  50000000.0    0.0           Teen
# 4      967   2800000.0    100000.0    0.0       Everyone
#
#                       Genres      Last Updated
# 0               Art & Design   January 7, 2018
# 1  Art & Design;Pretend Play  January 15, 2018
# 2               Art & Design    August 1, 2018
# 3               Art & Design      June 8, 2018
# 4    Art & Design;Creativity     June 20, 2018

# %%
pd.Series(dict(Counter(app['Category']))).sort_values()
# Out:
# BEAUTY                   53
# PARENTING                60
# COMICS                   60
# EVENTS                   64
# ART_AND_DESIGN           65
# WEATHER                  82
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# HOUSE_AND_HOME           88
# FOOD_AND_DRINK          127
# MAPS_AND_NAVIGATION     137
# ENTERTAINMENT           149
# EDUCATION               156
# VIDEO_PLAYERS           175
# BOOKS_AND_REFERENCE     231
# DATING                  234
# TRAVEL_AND_LOCAL        258
# SHOPPING                260
# NEWS_AND_MAGAZINES      283
# SOCIAL                  295
# PHOTOGRAPHY             335
# HEALTH_AND_FITNESS      341
# FINANCE                 366
# LIFESTYLE               382
# SPORTS                  384
# COMMUNICATION           387
# PERSONALIZATION         392
# PRODUCTIVITY            424
# BUSINESS                460
# MEDICAL                 463
# TOOLS                   843
# GAME                   1144
# FAMILY                 1972
# dtype: int64

# %%
app[app['Category'] == 'TOOLS'].describe()
# Out:
#            Rating       Reviews          Size      Installs       Price
# count  734.000000  8.430000e+02  7.390000e+02  8.430000e+02  843.000000
# mean     4.047411  3.240629e+05  8.771250e+06  1.358573e+07    0.317023
# std      0.616143  2.118483e+06  1.125434e+07  7.246704e+07    1.478440
# min      1.000000  0.000000e+00  2.500000e+04  1.000000e+00    0.000000
# 25%      3.800000  2.900000e+01  2.300000e+06  1.000000e+03    0.000000
# 50%      4.200000  5.220000e+02  4.200000e+06  5.000000e+04    0.000000
# 75%      4.400000  2.334750e+04  1.050000e+07  1.000000e+06    0.000000
# max      5.000000  4.291653e+07  9.900000e+07  1.000000e+09   25.990000

# %%
data1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews        Size    Installs  Price Content Rating  \
# 0      159  19000000.0     10000.0    0.0       Everyone
# 1      967  14000000.0    500000.0    0.0       Everyone
# 2    87510   8700000.0   5000000.0    0.0       Everyone
# 3   215644  25000000.0  50000000.0    0.0           Teen
# 4      967   2800000.0    100000.0    0.0       Everyone
#
#                       Genres      Last Updated
# 0               Art & Design   January 7, 2018
# 1  Art & Design;Pretend Play  January 15, 2018
# 2               Art & Design    August 1, 2018
# 3               Art & Design      June 8, 2018
# 4    Art & Design;Creativity     June 20, 2018

# %%
data2.head()
# Out:
#    Unnamed: 0                    App  \
# 0           0  10 Best Foods for You
# 1           1  10 Best Foods for You
# 2           2  10 Best Foods for You
# 3           3  10 Best Foods for You
# 4           4  10 Best Foods for You
#
#                                    Translated_Review Sentiment  \
# 0  I like eat delicious food. That's I'm cooking ...  Positive
# 1    This help eating healthy exercise regular basis  Positive
# 2         Works great especially going grocery store  Positive
# 3                                       Best idea us  Positive
# 4                                           Best way  Positive
#
#    Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.00                0.533333
# 1                0.25                0.288462
# 2                0.40                0.875000
# 3                1.00                0.300000
# 4                1.00                0.300000

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.title("요일 별 전체 팁의 Violin Plot")
plt.show()

# %%
category_mean = app.groupby(['Category'])['Installs','Reviews'].mean()
# Out:
# C:\Users\82107\AppData\Local\Temp/ipykernel_34020/112213859.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   category_mean = app.groupby(['Category'])['Installs','Reviews'].mean()

# %%
fig = plt.figure(figsize =(15,7))
ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx()
width =0.3
category_mean['Installs'].plot(kind='bar',color='chocolate',ax=ax,width=width, position=0,)
category_mean['Reviews'].plot(kind='bar',color='darkorange', ax=ax2,width = width,position=1)
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
sns.distplot(x = app[''])

# %%
sns.distplot(x = 'Category', dis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34020/2098006722.py in <module>
# ----> 1 sns.distplot(x = app['Category'], y = 'Installs')
#
# TypeError: distplot() got an unexpected keyword argument 'y'

# %%
plt.figure(figsize = (20,7))
sns.barplot( x = 'Category', y = 'Installs',data = category_mean.sort_values('Installs',ascending = False).reset_index()[:7],palette='r')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Installs'>

# %%
plt.figure(figsize = (70,40))
sns.violinplot(x ='Category', y = 'Installs', data = app,width = 5, linewidth= 30)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Installs'>

# %%
data1_app_count = pd.DataFrame(data1.groupby('Category').count()['App'])
data1_app_count = data1_app_count.sort_values(by='App', ascending = False)
data1_app_count.head(10)
# Out:
#                   App
# Category
# FAMILY           1972
# GAME             1144
# TOOLS             843
# MEDICAL           463
# BUSINESS          460
# PRODUCTIVITY      424
# PERSONALIZATION   392
# COMMUNICATION     387
# SPORTS            384
# LIFESTYLE         382

# %%
app.sort_values(by = 'Rating', ascending = False).head(60)
# Out:
#                                               App             Category  \
# 9056                  Santa's Monster Shootout DX                 GAME
# 8395                                        DG TV   NEWS_AND_MAGAZINES
# 8493                          PK and DK Audio App               FAMILY
# 6330                    HON. B.J. ACS COLLEGE ALE               FAMILY
# 6342                                     BJ Foods             BUSINESS
# 6363                          Read it easy for BK            LIFESTYLE
# 9766                                    ER Assist         PRODUCTIVITY
# 6364                              BK Video Status               FAMILY
# 6372                        BK Formula Calculator                TOOLS
# 6375                            Dr Bk Sachin bhai            LIFESTYLE
# 9806                         Dr. ES PV Calculator                TOOLS
# 9810              ES Billing System (Offline App)         PRODUCTIVITY
# 6391                        BK Arogyam Task Track             BUSINESS
# 9815                                     ES Solar             BUSINESS
# 6396                                 Bk Usha behn            LIFESTYLE
# 6398                                  BK Gold App              FINANCE
# 6422                           BL Flowers Digital             SHOPPING
# 4539                R Programing Offline Tutorial  BOOKS_AND_REFERENCE
# 8417                                 D-H Pharmacy            LIFESTYLE
# 9705                                     EP Radio               FAMILY
# 9701                          EP Church Annapolis            LIFESTYLE
# 6275                                       BI APP              FINANCE
# 8572           DM Buddy » Learn Digital Marketing               FAMILY
# 8596                                  DN Employee               FAMILY
# 8591                                      DN Blog               SOCIAL
# 6232                             Bh Public School               FAMILY
# 612                 American Girls Mobile Numbers               DATING
# 615                                  Awake Dating               DATING
# 329                  Hojiboy Tojiboyev Life Hacks               COMICS
# 8582                    Disciple Maker’s (DM) Lab               FAMILY
# 633                         Spine- The dating app               DATING
# 6272                                Propel BI APP             BUSINESS
# 6238                                   Barbers.BH            LIFESTYLE
# 9659                                      FAST EO               EVENTS
# 636    Girls Live Talk - Free Text and Video Chat               DATING
# 640                       Online Girls Chat Group               DATING
# 654               Speeding Joyride & Car Meet App               DATING
# 6266                                      BI News   NEWS_AND_MAGAZINES
# 8526                             DL Image Manager         PRODUCTIVITY
# 8411                                       DH-UFO               FAMILY
# 4477                    Android P Style Icon Pack      PERSONALIZATION
# 6171                                     BG Guide     TRAVEL_AND_LOCAL
# 4452                              P-Home for KLWP      PERSONALIZATION
# 8234                                   DB Pickles             BUSINESS
# 8230                                      DB HOME            LIFESTYLE
# 6726                COMSATS BOOK STORE FOR BS(CS)               FAMILY
# 6727                                    BS-Mobile        COMMUNICATION
# 6783                              Wifi BT Scanner               FAMILY
# 3957                                 ADS-B Driver                TOOLS
# 6807                                    Jabbla BT                TOOLS
# 2262     Super Hearing Secret Voices Recorder PRO              MEDICAL
# 6816                                     BU Study               FAMILY
# 10266                       Noticias FC Barcelona   NEWS_AND_MAGAZINES
# 8159                                    CZ Kompas                TOOLS
# 6823               Barisal University App-BU Face               FAMILY
# 2271                               FHR 5-Tier 2.0              MEDICAL
# 8146                                      CZ-Help  BOOKS_AND_REFERENCE
# 6840                        Catholic La Bu Zo Kam  BOOKS_AND_REFERENCE
# 6851                               BV Mobile Apps         PRODUCTIVITY
# 6852                                           BV        COMMUNICATION
#
#        Rating  Reviews        Size  Installs  Price Content Rating  \
# 9056      5.0        4  33000000.0      50.0   1.99           Teen
# 8395      5.0        3   5700000.0     100.0   0.00       Everyone
# 8493      5.0        2   3900000.0     100.0   0.00       Everyone
# 6330      5.0        3   1800000.0     100.0   0.00     Mature 17+
# 6342      5.0        3   1500000.0      10.0   0.00       Everyone
# 6363      5.0        1   3200000.0      50.0   0.00       Everyone
# 9766      5.0        3  28000000.0      10.0   0.00       Everyone
# 6364      5.0       13   2100000.0     100.0   0.00       Everyone
head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
for category in data1['Category'].unique():
  print(category)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION
# 1.9

# %%
data1.loc[[10472]]
# Out:
#                                            App Category  Rating Reviews  Size  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9     NaN    3.0M   1.0
#
#       Installs Type  Price Content Rating             Genres Last Updated  \
# 10472     Free    0    0.0            NaN  February 11, 2018       1.0.19
#
#       Current Ver Android Ver
# 10472  4.0 and up         NaN

# %%
data1.drop(10472, inplace = True)

# %%
data1['Reviews'] = pd.to_numeric(data1['Reviews'])
data1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size     Installs  Type  Price Content Rating  \
# 0         4.1      159  19.0      10,000+  Free    0.0       Everyone
# 1         3.9      967  14.0     500,000+  Free    0.0       Everyone
# 2         4.7    87510   8.7   5,000,000+  Free    0.0       Everyone
# 3         4.5   215644  25.0  50,000,000+  Free    0.0           Teen
# 4         4.3      967   2.8     100,000+  Free    0.0       Everyone
# ...       ...      ...   ...          ...   ...    ...            ...
# 10836     4.5       38  53.0       5,000+  Free    0.0       Everyone
# 10837     5.0        4   3.6         100+  Free    0.0       Everyone
# 10838     NaN        3   9.5       1,000+  Free    0.0       Everyone
# 10839     4.5      114   NaN       1,000+  Free    0.0     Mature 17+
# 10840     4.5   398307  19.0  10,000,000+  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                 1.0
# 10838                    Medical  January 20, 2017                 1.0
# 10839          Books & Reference  January 19, 2015  Varies with device
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10840 rows x 13 columns]

# %%
for installs in data1['Installs'].unique():
  print(installs)
# Out:
# 10,000+
# 500,000+
# 5,000,000+
# 50,000,000+
# 100,000+
# 50,000+
# 1,000,000+
# 10,000,000+
# 5,000+
# 100,000,000+
# 1,000,000,000+
# 1,000+
# 500,000,000+
# 50+
# 100+
# 500+
# 10+
# 1+
# 5+
# 0+
# 0

# %%
data1['Installs'] = data1['Installs'].str.replace(',', '', regex = True)

# %%
data1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size   Installs  Type  Price Content Rating  \
# 0         4.1      159  19.0     10000+  Free    0.0       Everyone
# 1         3.9      967  14.0    500000+  Free    0.0       Everyone
# 2         4.7    87510   8.7   5000000+  Free    0.0       Everyone
# 3         4.5   215644  25.0  50000000+  Free    0.0           Teen
# 4         4.3      967   2.8    100000+  Free    0.0       Everyone
# ...       ...      ...   ...        ...   ...    ...            ...
# 10836     4.5       38  53.0      5000+  Free    0.0       Everyone
# 10837     5.0        4   3.6       100+  Free    0.0       Everyone
# 10838     NaN        3   9.5      1000+  Free    0.0       Everyone
# 10839     4.5      114   NaN      1000+  Free    0.0     Mature 17+
# 10840     4.5   398307  19.0  10000000+  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                 1.0
# 10838                    Medical  January 20, 2017                 1.0
# 10839          Books & Reference  January 19, 2015  Varies with device
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10840 rows x 13 columns]

# %%
def removeplus(num):
  if num[-1] == '+':
    return int(num[:-1])
  else:
    return int(num)

# %%
data1['Installs'] = data1['Installs'].apply(removeplus)

# %%
data1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
for type in data1['Type'].unique():
  print(type)
# Out:
# Free
# Paid
# nan

# %%
for contentr in data1['Content Rating'].unique():
  print(contentr)
# Out:
# Everyone
# Teen
# Everyone 10+
# Mature 17+
# Adults only 18+
# Unrated

# %%
data1 = data1.drop(['Genres', 'Last Updated', 'Current Ver'], axis = 1)
data1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 0         4.1      159  19.0     10000  Free    0.0       Everyone
# 1         3.9      967  14.0    500000  Free    0.0       Everyone
# 2         4.7    87510   8.7   5000000  Free    0.0       Everyone
# 3         4.5   215644  25.0  50000000  Free    0.0           Teen
# 4         4.3      967   2.8    100000  Free    0.0       Everyone
# ...       ...      ...   ...       ...   ...    ...            ...
# 10836     4.5       38  53.0      5000  Free    0.0       Everyone
# 10837     5.0        4   3.6       100  Free    0.0       Everyone
# 10838     NaN        3   9.5      1000  Free    0.0       Everyone
# 10839     4.5      114   NaN      1000  Free    0.0     Mature 17+
# 10840     4.5   398307  19.0  10000000  Free    0.0       Everyone
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10840 rows x 10 columns]

# %%
data1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Android Ver          2
# dtype: int64

# %%
data1['Rating'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838     True
# 10839    False
# 10840    False
# Name: Rating, Length: 10840, dtype: bool

# %%
from sklearn.impute import SimpleImputer

# %%
imputer_m = SimpleImputer(missing_values = np.nan, strategy = 'median')

data1['Size'] = imputer_m.fit_transform(data1[['Size']])

# %%
data1['Rating'] = imputer_m.fit_transform(data1[['Rating']])

# %%
data1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Android Ver       2
# dtype: int64

# %%
data1.dropna(inplace = True)
data1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 0         4.1      159  19.0     10000  Free    0.0       Everyone
# 1         3.9      967  14.0    500000  Free    0.0       Everyone
# 2         4.7    87510   8.7   5000000  Free    0.0       Everyone
# 3         4.5   215644  25.0  50000000  Free    0.0           Teen
# 4         4.3      967   2.8    100000  Free    0.0       Everyone
# ...       ...      ...   ...       ...   ...    ...            ...
# 10836     4.5       38  53.0      5000  Free    0.0       Everyone
# 10837     5.0        4   3.6       100  Free    0.0       Everyone
# 10838     4.3        3   9.5      1000  Free    0.0       Everyone
# 10839     4.5      114  13.0      1000  Free    0.0     Mature 17+
# 10840     4.5   398307  19.0  10000000  Free    0.0       Everyone
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with
# 1704     4.6  44891723  98.0   100000000  Free    0.0   Everyone 10+
# 1670     4.6  44891723  98.0   100000000  Free    0.0   Everyone 10+
# 3986     4.6  44881447  98.0   100000000  Free    0.0   Everyone 10+
# 4005     4.7  42916526  13.0   500000000  Free    0.0       Everyone
# 1917     4.5  27725352  76.0  1000000000  Free    0.0   Everyone 10+
# 1872     4.5  27725352  76.0  1000000000  Free    0.0   Everyone 10+
# 1750     4.5  27724094  76.0  1000000000  Free    0.0   Everyone 10+
# 1700     4.5  27723193  76.0  1000000000  Free    0.0   Everyone 10+
# 1654     4.5  27722264  76.0  1000000000  Free    0.0   Everyone 10+
# 3896     4.5  27711703  76.0  1000000000  Free    0.0   Everyone 10+
# 3665     4.3  25655305  13.0  1000000000  Free    0.0           Teen
# 3928     4.3  25623548  13.0  1000000000  Free    0.0           Teen
# 7536     4.7  24900999  13.0   500000000  Free    0.0       Everyone
# 1878     4.6  23136735  97.0   100000000  Free    0.0   Everyone 10+
# 1721     4.6  23134775  97.0   100000000  Free    0.0   Everyone 10+
# 1660     4.6  23133508  97.0   100000000  Free    0.0   Everyone 10+
# 3987     4.6  23125280  97.0   100000000  Free    0.0   Everyone 10+
#
#              Android Ver
# 2544  Varies with device
# 3943  Varies with device
# 381   Varies with device
# 336   Varies with device
# 3904  Varies with device
# 2604  Varies with device
# 2611  Varies with device
# 2545  Varies with device
# 3909  Varies with device
# 382   Varies with device
# 4104  Varies with device
# 335   Varies with device
# 1879          4.1 and up
# 1704          4.1 and up
# 1670          4.1 and up
# 3986          4.1 and up
# 4005  Varies with device
# 1917          4.1 and up
# 1872          4.1 and up
# 1750          4.1 and up
# 1700          4.1 and up
# 1654          4.1 and up
# 3896          4.1 and up
# 3665  Varies with device
# 3928  Varies with device
# 7536  Varies with device
# 1878          4.1 and up
# 1721          4.1 and up
# 1660          4.1 and up
# 3987          4.1 and up

# %%
plt.figure(figsize = (15, 5))
sns.barplot(x='App', y='Reviews', data = data1_r_rank)
plt.xticks(rotation = 90)
plt.ylabel('Reviews')
plt.title('Top 10 Apps that Have the Most Number of Reviews')
plt.show()

# %%
### review 수 높은 순대로 정렬.
### Facebook, WhatsApp, Instagram, Messenger, Clash of Clans, Youtube 등 이름만 들어도 아는 어플들이 많음.
### review 수는 앱의 성공을 판단하는 데에 중요한 지표가 되지 않을까?

# %%
data1_i_rank = data1.sort_values(by = 'Installs', ascending = False)
data1_i_rank = data1_i_rank.head(20)
data1_i_rank
# Out:
#                                            App             Category  Rating  \
# 3896                            Subway Surfers                 GAME     4.5
# 3943                                  Facebook               SOCIAL     4.1
# 335   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 3523                              Google Drive         PRODUCTIVITY     4.4
# 3565                              Google Drive         PRODUCTIVITY     4.4
# 2884                             Google Photos          PHOTOGRAPHY     4.5
# 3665                                   YouTube        VIDEO_PLAYERS     4.3
# 2853                             Google Photos          PHOTOGRAPHY     4.5
# 4234             Skype - free IM & video calls        COMMUNICATION     4.1
# 3687                   Google Play Movies & TV        VIDEO_PLAYERS     3.7
# 2808                             Google Photos          PHOTOGRAPHY     4.5
# 4170                              Google Drive         PRODUCTIVITY     4.4
# 4153                                  Hangouts        COMMUNICATION     4.0
# 4150                                    Google                TOOLS     4.4
# 152                          Google Play Books  BOOKS_AND_REFERENCE     3.9
# 4144                                   Google+               SOCIAL     4.2
# 4104  Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 4098                 Maps - Navigate & Explore     TRAVEL_AND_LOCAL     4.3
# 4096                                     Gmail        COMMUNICATION     4.3
# 3736                               Google News   NEWS_AND_MAGAZINES     3.9
#
#        Reviews  Size    Installs  Type  Price Content Rating  \
# 3896  27711703  76.0  1000000000  Free    0.0   Everyone 10+
# 3943  78128208  13.0  1000000000  Free    0.0           Teen
# 335   56642847  13.0  1000000000  Free    0.0       Everyone
# 3523   2731211  13.0  1000000000  Free    0.0       Everyone
# 3565   2731211  13.0  1000000000  Free    0.0       Everyone
# 2884  10859051  13.0  1000000000  Free    0.0       Everyone
# 3665  25655305  13.0  1000000000  Free    0.0           Teen
# 2853  10858538  13.0  1000000000  Free    0.0       Everyone
# 4234  10484169  13.0  1000000000  Free    0.0       Everyone
# 3687    906384  13.0  1000000000  Free    0.0           Teen
# 2808  10858556  13.0  1000000000  Free    0.0       Everyone
# 4170   2728941  13.0  1000000000  Free    0.0       Everyone
# 4153   3419464  13.0  1000000000  Free    0.0       Everyone
# 4150   8021623  13.0  1000000000  Free    0.0       Everyone
# 152    1433233  13.0  1000000000  Free    0.0           Teen
# 4144   4828372  13.0  1000000000  Free    0.0           Teen
# 4104  56642847  13.0  1000000000  Free    0.0       Everyone
# 4098   9231613  13.0  1000000000  Free    0.0       Everyone
# 4096   4604324  13.0  1000000000  Free    0.0       Everyone
# 3736    877635  13.0  1000000000  Free    0.0           Teen
#
#              Android Ver
# 3896          4.1 and up
# 3943  Varies with device
# 335   Varies with device
# 3523  Varies with device
# 3565  Varies with device
# 2884  Varies with device
# 3665  Varies with device
# 2853  Varies with device
# 4234  Varies with device
# 3687  Varies with device
# 2808  Varies with device
# 4170  Varies with device
# 4153  Varies with device
# 4150  Varies with device
# 152   Varies with device
# 4144  Varies with device
# 4104  Varies with device
# 4098  Varies with device
# 4096  Varies with device
# 3736          4.4 and up

# %%
plt.figure(figsize = (15, 5))
sns.barplot(x='App', y='Installs', data = data1_i_rank)
plt.xticks(rotation = 90)
plt.ylabel('Installs')
plt.title('Top 15 Apps that Have the Most Number of Reviews')
plt.show()

# %%
### 그래프 상의 어플은 전부 다 installs 가 1000000000+ 임.
### 목록을 살펴보면 주로 일상 생활을 편리하게 하는 데에 도움을 주는 어플임. (지도, 메신저, 메일, 뉴스 등...)

## 실용적인 어플은 사람들이 필요에 의해 찾게 되니 다운로드 수가 많을 수밖에...?

# %%
### installs 가 많은 어플은 이름만 들어도 우리가 아는 어플임.
### 근데 이 어플들의 rating을 보면 좋지 않은 것도 많이 있음.

### rating은 어플의 성공에 큰 영향을 미치진 않을 것 같다...

# %%
category_share = ( data1.Category.value_counts() / data1.Category.value_counts().sum() ) * 100
category_share
# Out:
# FAMILY                 18.187690
# GAME                   10.556427
# TOOLS                   7.778906
# MEDICAL                 4.272400
# BUSINESS                4.244717
# PRODUCTIVITY            3.912522
# PERSONALIZATION         3.598782
# COMMUNICATION           3.571099
# SPORTS                  3.543416
# LIFESTYLE               3.524961
# FINANCE                 3.377318
# HEALTH_AND_FITNESS      3.146627
# PHOTOGRAPHY             3.091261
# SOCIAL                  2.722156
# NEWS_AND_MAGAZINES      2.611424
# SHOPPING                2.399188
# TRAVEL_AND_LOCAL        2.380733
# DATING                  2.159269
# BOOKS_AND_REFERENCE     2.131586
# VIDEO_PLAYERS           1.614838
# EDUCATION               1.439513
# ENTERTAINMENT           1.374919
# MAPS_AND_NAVIGATION     1.264188
# FOOD_AND_DRINK          1.171911
# HOUSE_AND_HOME          0.812033
# AUTO_AND_VEHICLES       0.784350
# LIBRARIES_AND_DEMO      0.784350
# WEATHER                 0.756667
# ART_AND_DESIGN          0.599797
# EVENTS                  0.590569
# PARENTING               0.553659
# COMICS                  0.553659
# BEAUTY                  0.489065
# Name: Category, dtype: float64

# %%
plt.figure(figsize=(8, 8))

category_share.plot.pie(autopct='%1.2f%%')
plt.ylabel('')
plt.title('Market Share for Each Categories', pad = 30)
plt.axis('equal')
plt.show()

# %%
price_app = ( data1.Price.value_counts() / data1.Price.value_counts().sum() ) * 100
price_app
# Out:
# 0.0      92.627111
# 1.0       1.845529
# 3.0       1.338009
# 2.0       1.033496
# 5.0       0.784350
# 4.0       0.719756
# 6.0       0.322968
# 10.0      0.221464
# 7.0       0.138415
# 400.0     0.119959
# 15.0      0.110732
# 8.0       0.083049
# 20.0      0.064594
# 30.0      0.064594
# 25.0      0.064594
# 9.0       0.064594
# 13.0      0.046138
# 12.0      0.046138
# 17.0      0.027683
# 14.0      0.027683
# 80.0      0.018455
# 19.0      0.018455
# 18.0      0.018455
# 40.0      0.018455
# 34.0      0.018455
# 11.0      0.018455
# 90.0      0.009228
# 31.0      0.009228
# 200.0     0.009228
# 29.0      0.009228
# 155.0     0.009228
# 47.0      0.009228
# 110.0     0.009228
# 16.0      0.009228
# 390.0     0.009228
# 38.0      0.009228
# 380.0     0.009228
# 300.0     0.009228
# 26.0      0.009228
# 75.0      0.009228
# 395.0     0.009228
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(8, 8))

price_app.plot.pie(autopct='%1.2f%%')
plt.ylabel('')
plt.title('Price for Apps', pad = 10)
plt.axis('equal')
plt.show()

# %%
### 시장 점유율은 Family가 압도적으로 높음.
### Family, Game, Tools 순으로 ...

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
categories = data1.groupby('Category')
category_installs_sum = categories[['Installs']].sum()
category_installs_sum = category_installs_sum.reset_index()
category_installs_sum = category_installs_sum.sort_values(by = ['Installs'], ascending = False)

plt.figure(figsize=(15, 5))
sns.barplot(x='Category', y='Installs', data = category_installs_sum)
plt.xticks(rotation = 90)
plt.ylabel('Installs')
plt.title('Installs For Each Category')
plt.show()

# %%
### 'game'과 'communication' 분야의 어플이 다운로드 수가 가장 많았음.
### 다운로드 수가 많다는 건 그만큼 필요로 하는 사람이 많다는 것.

# %%
data1.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.063185  0.053525  0.045518 -0.019366
# Reviews   0.063185  1.000000  0.104010  0.643119 -0.009634
# Size      0.053525  0.104010  1.000000  0.047668 -0.019307
# Installs  0.045518  0.643119  0.047668  1.000000 -0.011649
# Price    -0.019366 -0.009634 -0.019307 -0.011649  1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(data = data1.corr(), annot=True, fmt = '.4f', linewidths=.5)

# %%
### 일단 수치적으로 상관 계수가 높았던 것은 review 와 installs.
### 더 자세히 살펴봐야 알겠지만 review와 installs 간의 관계를 유심히 살펴보자.

# %%
pp = sns.pairplot(data = data1, kind = "reg")
pp.fig.suptitle('Google Play Store App\'s Pairplot')
pp.fig.subplots_adjust(top = 0.95)

plt.show()

# %%
### pairplot으로 보니 price는 reviews와 installs와 뚜렷한 관계를 보이지 않음.
### 92%의 어플이 무료... 시장성을 챙기려면 무료로 어플을 공급해야 하지 않을까?

### size가 클수록 reviews와 installs 수가 어느 정도 커지는 것을 발견할 수 있음.
### size가 크다는 것은 곧 해당 어플에 담겨 있는 컨텐츠가 많다는 것을 의미함. 사용자가 즐길 거리가 더 많다는 거.

# %%
app_game = data1[data1['Category'] == 'GAME']
app_game.sort_values(by = 'Installs', ascending = False).head(30)
# Out:
#                                                    App Category  Rating  \
# 1750                                    Subway Surfers     GAME     4.5
# 1654                                    Subway Surfers     GAME     4.5
# 1700                                    Subway Surfers     GAME     4.5
# 1917                                    Subway Surfers     GAME     4.5
# 3896                                    Subway Surfers     GAME     4.5
# 1872                                    Subway Surfers     GAME     4.5
# 1886                                      Temple Run 2     GAME     4.3
# 1705                                  Candy Crush Saga     GAME     4.4
# 1920                                      Temple Run 2     GAME     4.3
# 1702                                               Pou     GAME     4.3
# 1722                                    My Talking Tom     GAME     4.5
# 1908                                    My Talking Tom     GAME     4.5
# 1729                                      Temple Run 2     GAME     4.3
# 1885                                               Pou     GAME     4.3
# 4041                                      Temple Run 2     GAME     4.3
# 1869                                  Candy Crush Saga     GAME     4.4
# 1966                                  Candy Crush Saga     GAME     4.4
# 1759                                      Temple Run 2     GAME     4.3
# 1842                                  Candy Crush Saga     GAME     4.4
# 1662                                               Pou     GAME     4.3
# 1661                                      Temple Run 2     GAME     4.3
# 1655                                  Candy Crush Saga     GAME     4.4
# 1751                                  Candy Crush Saga     GAME     4.4
# 1921                                        slither.io     GAME     4.4
# 1923                              Talking Tom Gold Run     GAME     4.6
