# %% [markdown]
# # 필요한 것 Import

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='NanumBarunGothic')
from matplotlib import rcParams

# %% [markdown]
# # 전처리

# %% [markdown]
# ## 상가업소정보 데이터
# - 20년 3월(코로나 이전), 21년6월, 22년 3월(코로나 이후) 비교

# %%
data19_1 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_2019/소상공인시장진흥공단_상가업소정보_201903_01.csv")

# %%
data19_2 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_2019/소상공인시장진흥공단_상가업소정보_201903_02.csv")
data19_3 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_2019/소상공인시장진흥공단_상가업소정보_201903_03.csv")
data19_4 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_2019/소상공인시장진흥공단_상가업소정보_201903_04.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (35,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#서울 # 부산 
data19_1['시도명'].unique()
# Out:
# array(['서울특별시', '부산광역시'], dtype=object)

# %%
# 대구, 인천, 광주, 울산, 대전, 세종
data19_2['시도명'].unique()
# Out:
# array(['대구광역시', '인천광역시', '광주광역시', '울산광역시', '대전광역시', '세종특별자치시'],
#       dtype=object)

# %%
#경기도, 충청북도, 강원도
data19_3['시도명'].unique()
# Out:
# array(['경기도', '충청북도', '강원도'], dtype=object)

# %%
#충청남도', '전라남도', '전라북도', '경상북도', '제주특별자치도', '경상남도
data19_4['시도명'].unique()
# Out:
# array(['충청남도', '전라남도', '전라북도', '경상북도', '제주특별자치도', '경상남도'], dtype=object)

# %%
#19년 데이터
us19 = data19_2[data19_2['시도명']=='울산광역시']
bs19 = data19_1[data19_1['시도명']=='부산광역시']
kn19 = data19_4[data19_4['시도명']=='경상남도']
kb19 = data19_4[data19_4['시도명']=='경상북도']

# %%
#20년 3월 data
kn20 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20200331/상가업소정보_경남_202003.csv",sep="|")
kb20 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20200331/상가업소정보_경북_202003.csv",sep="|")
bs20 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20200331/상가업소정보_부산_202003.csv",sep='|')
us20 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20200331/상가업소정보_울산_202003.csv",sep='|')

#21년 6월 data
kn21 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20210630/소상공인시장진흥공단_상가(상권)정보_경남_202106.csv")
kb21 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20210630/소상공인시장진흥공단_상가(상권)정보_경북_202106.csv")
bs21 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20210630/소상공인시장진흥공단_상가(상권)정보_부산_202106.csv")
us21 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20210630/소상공인시장진흥공단_상가(상권)정보_울산_202106.csv")

#22년 3월 data
kn22 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20220331/소상공인시장진흥공단_상가(상권)정보_경남_202203.csv")
kb22 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20220331/소상공인시장진흥공단_상가(상권)정보_경북_202203.csv")
bs22 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20220331/소상공인시장진흥공단_상가(상권)정보_부산_202203.csv")
us22 = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/상가(상권)정보_20220331/소상공인시장진흥공단_상가(상권)정보_울산_202203.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
us19.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
bs19.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
kn19.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
kb19.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
kn20.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
kn21.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
kn22.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
kb20.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
kb21.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
kb22.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
bs20.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
bs21.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
bs22.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
us20.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
us21.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
us22.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)

# %%
kn20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180137 entries, 0 to 180136
# Data columns (total 16 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   상가업소번호    180137 non-null  int64
#  1   상호명       180137 non-null  object
#  2   지점명       21959 non-null   object
#  3   상권업종대분류명  180137 non-null  object
#  4   상권업종중분류명  180137 non-null  object
#  5   상권업종소분류명  180137 non-null  object
#  6   표준산업분류명   169229 non-null  object
#  7   시군구명      180137 non-null  object
#  8   행정동명      180137 non-null  object
#  9   법정동명      180137 non-null  object
#  10  지번주소      180137 non-null  object
#  11  도로명       180137 non-null  object
#  12  동정보       9574 non-null    object
#  13  층정보       71795 non-null   object
#  14  경도        180137 non-null  float64
#  15  위도        180137 non-null  float64
# dtypes: float64(2), int64(1), object(13)
# memory usage: 22.0+ MB

# %%
kn20.isnull().sum()/len(kn20)
# Out:
# 상가업소번호      0.000000
# 상호명         0.000000
# 지점명         0.878098
# 상권업종대분류명    0.000000
# 상권업종중분류명    0.000000
# 상권업종소분류명    0.000000
# 표준산업분류명     0.060554
# 시군구명        0.000000
# 행정동명        0.000000
# 법정동명        0.000000
# 지번주소        0.000000
# 도로명         0.000000
# 동정보         0.946852
# 층정보         0.601442
# 경도          0.000000
# 위도          0.000000
# dtype: float64

# %%
#결측치 대체
kn20['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
kn20['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
kn20['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
kn20['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
kn20['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

kn21['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
kn21['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
kn21['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
kn21['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
kn21['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

kn22['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
kn22['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
kn22['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
kn22['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
kn22['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

kb20['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
kb20['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
kb20['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
kb20['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
kb20['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

kb21['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
kb21['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
kb21['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
kb21['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
kb21['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

kb22['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
kb22['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
kb22['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
kb22['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
kb22['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

bs20['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
bs20['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
bs20['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
bs20['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
bs20['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

bs21['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
bs21['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
bs21['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
bs21['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
bs21['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

bs22['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
bs22['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
bs22['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
bs22['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
bs22['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

us20['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
us20['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
us20['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
us20['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
us20['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

us21['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
us21['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
us21['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
us21['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
us21['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

us22['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
us22['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
us22['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
us22['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
us22['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

# %%
us19['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
us19['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
us19['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
us19['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
us19['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

bs19['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
bs19['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
bs19['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
bs19['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
bs19['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

kn19['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
kn19['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
kn19['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
kn19['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
kn19['층정보'].replace(to_replace=np.nan,value="0",inplace=True)

kb19['표준산업분류명'].replace(to_replace=np.nan,value="0",inplace=True)
kb19['행정동명'].replace(to_replace=np.nan,value="0",inplace=True)
kb19['지점명'].replace(to_replace=np.nan,value="0",inplace=True)
kb19['동정보'].replace(to_replace=np.nan,value="0",inplace=True)
kb19['층정보'].replace(to_replace=np.nan,value="0",inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %% [markdown]
# ## 인구 데이터

# %%
pop = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/행정구역_시군구_별__성별_인구수_20220731072802.csv",encoding='cp949')

# %%
pop
# Out:
#     행정구역(시군구)별   2022.06  2022.06.1  2022.06.2      2019     2019.1  \
# 0   행정구역(시군구)별  총인구수 (명)  남자인구수 (명)  여자인구수 (명)  총인구수 (명)  남자인구수 (명)
# 1           전국  51578178   25711784   25866394  51849861   25864816
# 2        서울특별시   9494807    4605655    4889152   9729107    4744059
# 3        부산광역시   3336737    1630944    1705793   3413841    1675417
# 4        대구광역시   2375306    1169571    1205735   2438031    1205286
# 5        인천광역시   2957066    1480432    1476634   2957026    1482249
# 6        광주광역시   1435378     709685     725693   1456468     720740
# 7        대전광역시   1448401     722517     725884   1474870     736607
# 8        울산광역시   1115609     573152     542457   1148019     589712
# 9      세종특별자치시    380215     189723     190492    340575     169845
# 10         경기도  13585967    6838396    6747571  13239666    6659995
# 11         강원도   1539064     774405     764659   1541502     775386
# 12        충청북도   1597118     811127     785991   1600007     810384
# ...

# %%
pop = pop.loc[:,['행정구역(시군구)별','2019','2020','2021','2022.06']]
pop
# Out:
#     행정구역(시군구)별      2019      2020      2021   2022.06
# 0   행정구역(시군구)별  총인구수 (명)  총인구수 (명)  총인구수 (명)  총인구수 (명)
# 1           전국  51849861  51829023  51638809  51578178
# 2        서울특별시   9729107   9668465   9509458   9494807
# 3        부산광역시   3413841   3391946   3350380   3336737
# 4        대구광역시   2438031   2418346   2385412   2375306
# 5        인천광역시   2957026   2942828   2948375   2957066
# 6        광주광역시   1456468   1450062   1441611   1435378
# 7        대전광역시   1474870   1463882   1452251   1448401
# 8        울산광역시   1148019   1136017   1121592   1115609
# 9      세종특별자치시    340575    355831    371895    380215
# 10         경기도  13239666  13427014  13565450  13585967
# 11         강원도   1541502   1542840   1538492   1539064
# 12        충청북도   1600007   1600837   1597427   1597118
# 13        충청남도   2123709   2121029   2119257   2120201
# 14        전라북도   1818917   1804104   1786855   1778279
# 15        전라남도   1868745   1851549   1832803   1826440
# ...

# %%
kn_pop = pop.loc[17,:]
kb_pop = pop.loc[16,:]
bs_pop = pop.loc[3,:]
us_pop = pop.loc[8,:]

# %%
kn_pop = pd.DataFrame(kn_pop).transpose().set_index('행정구역(시군구)별')
kb_pop = pd.DataFrame(kb_pop).transpose().set_index('행정구역(시군구)별')
bs_pop = pd.DataFrame(bs_pop).transpose().set_index('행정구역(시군구)별')
us_pop = pd.DataFrame(us_pop).transpose().set_index('행정구역(시군구)별')

# %%
kn_pop
# Out:
#                2019     2020     2021  2022.06
# 행정구역(시군구)별
# 경상남도        3362553  3340216  3314183  3295615

# %% [markdown]
# # 각 지역별 특징 파악

# %% [markdown]
# ## 경남

# %% [markdown]
# ### 업종대분류별 업소수

# %%
t_20 = table3['20년 총 업소수']
t_21 = table3['21년 총 업소수']
t_22 = table3['22년 총 업소수']

sizes_20 = [t_20[0],t_20[1],t_20[2],t_20[3],t_20[4],t_20[5],t_20[6],t_20[7]]
sizes_21 = [t_21[0],t_21[1],t_21[2],t_21[3],t_21[4],t_21[5],t_21[6],t_21[7]]
sizes_22 = [t_22[0],t_22[1],t_22[2],t_22[3],t_22[4],t_22[5],t_22[6],t_22[7]]

labels = ['관광/여가/오락','부동산','생활서비스','소매','숙박','스포츠','음식','학문/교육']

plt.subplot(131)
plt.pie(sizes_20,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10}
        )
plt.axis('equal')
plt.title("2020 경남")

plt.subplot(132)
plt.pie(sizes_21,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10})
plt.axis('equal')
plt.title("2021 경남")


plt.subplot(133)
plt.pie(sizes_22,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10})
plt.axis('equal')
plt.title("2022 경남")

plt.show()

# %% [markdown]
# 직관적으로 봤을 때 음식이 가장 큰 비중을 차지하는 것을 볼 수 있다.

# %%
#2019년 상권업종대분류명
table4_kn = pd.pivot_table(data = kn19, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table4_kn.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       176289
# 음식         67913
# 소매         55052
# 생활서비스      26397
# 학문/교육      13371
# 관광/여가/오락    4835
# 부동산         4509
# 숙박          4156
# 스포츠           56

# %%
#2020년 상권업종대분류명
table0_kn = pd.pivot_table(data = kn20, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table0_kn.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       180137
# 음식         69170
# 소매         55811
# 생활서비스      27817
# 학문/교육      13496
# 관광/여가/오락    4891
# 부동산         4604
# 숙박          4256
# 스포츠           92

# %%
#2021년 상권업종대분류명
table1_kn = pd.pivot_table(data = kn21, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table1_kn.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       160448
# 음식         65346
# 소매         47757
# 생활서비스      24706
# 학문/교육      10910
# 부동산         4155
# 숙박          3803
# 관광/여가/오락    3184
# 스포츠          587

# %%
#2022년 상권업종대분류명
table2_kn = pd.pivot_table(data = kn22, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table2_kn.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       155793
# 음식         59020
# 소매         47130
# 생활서비스      25304
# 학문/교육      10604
# 부동산         4782
# 숙박          3944
# 관광/여가/오락    3216
# 스포츠         1793

# %%
table3_kn = pd.concat([table4_kn,table0_kn, table1_kn, table2_kn], axis = 1)
table3_kn.columns = ['19년 총 업소수','20년 총 업소수', '21년 총 업소수', '22년 총 업소수']
table3_kn
# Out:
#           19년 총 업소수  20년 총 업소수  21년 총 업소수  22년 총 업소수
# 상권업종대분류명
# 관광/여가/오락       4835       4891       3184       3216
# 부동산            4509       4604       4155       4782
# 생활서비스         26397      27817      24706      25304
# 소매            55052      55811      47757      47130
# 숙박             4156       4256       3803       3944
# 스포츠              56         92        587       1793
# 음식            67913      69170      65346      59020
# 학문/교육         13371      13496      10910      10604
# All          176289     180137     160448     155793

# %%
table_kn_new = pd.concat([table0_kn, table1_kn, table2_kn],axis=0)

table_kn_new.drop('All',axis=0)
# Out:
#           상가업소번호
# 상권업종대분류명
# 관광/여가/오락    4891
# 부동산         4604
# 생활서비스      27817
# 소매         55811
# 숙박          4256
# 스포츠           92
# 음식         69170
# 학문/교육      13496
# 관광/여가/오락    3184
# 부동산         4155
# 생활서비스      24706
# 소매         47757
# 숙박          3803
# 스포츠          587
# 음식         65346
# 학문/교육      10910
# 관광/여가/오락    3216
# 부동산         4782
# 생활서비스      25304
# 소매         47130
# 숙박          3944
# 스포츠         1793
# 음식         59020
# 학문/교육      10604

# %%
table3_kn.transpose()
# Out:
# 상권업종대분류명   관광/여가/오락   부동산  생활서비스     소매    숙박   스포츠     음식  학문/교육     All
# 19년 총 업소수      4835  4509  26397  55052  4156    56  67913  13371  176289
# 20년 총 업소수      4891  4604  27817  55811  4256    92  69170  13496  180137
# 21년 총 업소수      3184  4155  24706  47757  3803   587  65346  10910  160448
# 22년 총 업소수      3216  4782  25304  47130  3944  1793  59020  10604  155793

# %%
table_kn_all = table3_kn.transpose()['All']
table_kn_all
# Out:
# 19년 총 업소수    176289
# 20년 총 업소수    180137
# 21년 총 업소수    160448
# 22년 총 업소수    155793
# Name: All, dtype: int64

# %%
rate_20_21 = (table3_kn['21년 총 업소수']-table3_kn['20년 총 업소수'])/table3_kn['20년 총 업소수']*100
rate_21_22 = (table3_kn['22년 총 업소수']-table3_kn['21년 총 업소수'])/table3_kn['21년 총 업소수']*100
rate_20_21.name = '20-21 증감률'
rate_21_22.name = '21-22 증감률'

# %%
#20,21,22 증감률 표
kn_rate = pd.concat([table3_kn,rate_20_21,rate_21_22],axis=1)
kn_rate
# Out:
#           19년 총 업소수  20년 총 업소수  21년 총 업소수  22년 총 업소수   20-21 증감률   21-22 증감률
# 상권업종대분류명
# 관광/여가/오락       4835       4891       3184       3216  -34.900838    1.005025
# 부동산            4509       4604       4155       4782   -9.752389   15.090253
# 생활서비스         26397      27817      24706      25304  -11.183808    2.420465
# 소매            55052      55811      47757      47130  -14.430847   -1.312897
# 숙박             4156       4256       3803       3944  -10.643797    3.707599
# 스포츠              56         92        587       1793  538.043478  205.451448
# 음식            67913      69170      65346      59020   -5.528408   -9.680776
# 학문/교육         13371      13496      10910      10604  -19.161233   -2.804766
# All          176289     180137     160448     155793  -10.930014   -2.901251

# %% [markdown]
# ![스크린샷 2022-07-29 오후 11.13.21.png](data:image/png;base64,...)

# %% [markdown]
# ### 업소 커버리지
#
# 한개의 업소 당 몇명의 인구를 감당할 수 있을까?
# 인구수/업소수

# %%
table3['2020인구수'] = 3340216
table3['2021인구수'] = 3314183
table3['2022인구수'] = 3295615

table3
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수  2020인구수  2021인구수  2022인구수
# 상권업종대분류명
# 관광/여가/오락       4891       3184       3216  3340216  3314183  3295615
# 부동산            4604       4155       4782  3340216  3314183  3295615
# 생활서비스         27817      24706      25304  3340216  3314183  3295615
# 소매            55811      47757      47130  3340216  3314183  3295615
# 숙박             4256       3803       3944  3340216  3314183  3295615
# 스포츠              92        587       1793  3340216  3314183  3295615
# 음식            69170      65346      59020  3340216  3314183  3295615
# 학문/교육         13496      10910      10604  3340216  3314183  3295615
# All          180137     160448     155793  3340216  3314183  3295615

# %%
# 인구 수 당 커버리지 : 업소 당 얼마나 많은 인구수를 감당할 수 있는지 (인구수/업소수)
table3['2020커버리지'] = table3['2020인구수']/table3['20년 총 업소수']
table3['2021커버리지'] = table3['2021인구수']/table3['21년 총 업소수']
table3['2022커버리지'] = table3['2022인구수']/table3['22년 총 업소수']


table3
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수  2020인구수  2021인구수  2022인구수  \
# 상권업종대분류명
# 관광/여가/오락       4891       3184       3216  3340216  3314183  3295615
# 부동산            4604       4155       4782  3340216  3314183  3295615
# 생활서비스         27817      24706      25304  3340216  3314183  3295615
# 소매            55811      47757      47130  3340216  3314183  3295615
# 숙박             4256       3803       3944  3340216  3314183  3295615
# 스포츠              92        587       1793  3340216  3314183  3295615
# 음식            69170      65346      59020  3340216  3314183  3295615
# 학문/교육         13496      10910      10604  3340216  3314183  3295615
# All          180137     160448     155793  3340216  3314183  3295615
#
#               2020커버리지     2021커버리지     2022커버리지
# 상권업종대분류명
# 관광/여가/오락    682.931098  1040.886621  1024.755908
# 부동산         725.503041   797.637304   689.170849
# 생활서비스       120.078226   134.144864   130.240871
# 소매           59.848704    69.396800    69.926056
# ...

# %%
kn_j = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/2주차_부산울산경북경남 분석/경남지역현황.csv")
kn_j
# Out:
#      행정구역       총가구수       총인구수   주요시설수   집객시설수 아파트면적(1m2)당 기준시가(원)      업소수  \
# 0    경상남도  1,375,996  3,368,020  13,316  18,873           4,694,424  174,259
# 1   ┗ 창원시    417,479  1,067,462   3,912   5,991           5,593,272   60,235
# 2   ┗ 진주시    140,303    347,856   1,316   1,858           4,360,199   18,749
# 3   ┗ 통영시     59,124    138,693     570     948           3,991,957    7,983
# 4   ┗ 사천시     50,677    115,169     508     714           3,215,522    6,389
# 5   ┗ 김해시    198,935    528,762   1,519   2,398           4,565,688   24,244
# 6   ┗ 밀양시     49,523    108,030     534     658           3,229,377    5,739
# 7   ┗ 거제시    102,540    257,287     797   1,456           5,515,436   11,459
# 8   ┗ 양산시    120,185    306,405     940   1,229           4,470,345   13,427
# 9   ┗ 의령군     14,384     28,246     206     159           3,130,637    1,297
# 10  ┗ 함안군     31,043     68,932     288     320           4,170,966    2,927
# ...

# %%
#경남 지역 현황
kn_j = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/2주차_부산울산경북경남 분석/경남지역현황.csv")

guyuk = kn_j['행정구역'].to_list()

for i in range(len(guyuk)):
  if guyuk[i].startswith("┗"):
    guyuk[i] = guyuk[i][2:]

kn_j['행정구역'] = pd.Series(guyuk)

kn_j.drop(0,axis=0)
kn_j = kn_j.sort_values(by=['행정구역'])
kn_j
# Out:
#     행정구역       총가구수       총인구수   주요시설수   집객시설수 아파트면적(1m2)당 기준시가(원)      업소수  \
# 7    거제시    102,540    257,287     797   1,456           5,515,436   11,459
# 17   거창군     27,987     63,239     434     372           2,802,977    3,177
# 0   경상남도  1,375,996  3,368,020  13,316  18,873           4,694,424  174,259
# 12   고성군     25,860     54,816     359     380           3,141,158    3,134
# 5    김해시    198,935    528,762   1,519   2,398           4,565,688   24,244
# 13   남해군     22,132     45,471     334     578           2,992,268    2,634
# 6    밀양시     49,523    108,030     534     658           3,229,377    5,739
# 4    사천시     50,677    115,169     508     714           3,215,522    6,389
# 15   산청군     18,207     36,228     243     350           2,994,276    1,973
# 8    양산시    120,185    306,405     940   1,229           4,470,345   13,427
# 9    의령군     14,384     28,246     206     159           3,130,637    1,297
# ...

# %% [markdown]
# ### 경남 지역별 업소수

# %%
pivot_kn = pd.pivot_table(data = kn22, index = "시군구명", columns = "상권업종대분류명", values = "상가업소번호", aggfunc = ['count'], 
                              fill_value = 0, margins=True, margins_name="합계")
pivot_kn
# Out:
#              count
# 상권업종대분류명  관광/여가/오락   부동산  생활서비스     소매    숙박   스포츠     음식  학문/교육      합계
# 시군구명
# 거제시            218   265   1582   2905   614   133   4583    858   11158
# 거창군             36    34    492   1018   107    29   1193    149    3058
# 고성군             38    63    415    943   115    10   1195    123    2902
# 김해시            397   966   3546   6078   158   285   7214   1695   20339
# 남해군             29    37    279    771   389    17   1121     75    2718
# 밀양시             69   128    847   1737   177    41   2241    236    5476
# 사천시             87   126    877   1760   152    77   2439    316    5834
# 산청군             30    25    195    623   212    19    743     37    1884
# 양산시            306   599   2240   3354   162   177   5229    860   12927
# 의령군              9    27    157    423    25    10    526     32    1209
# 진주시            429   534   2896   5459   254   203   6246   1463   17484
# ...

# %% [markdown]
# - 경상남도 내에 업소수가 가장 많은 시는 대표적으로 김해시, 양산시, 진주시, 창원시였다.

# %%
plt.figure(figsize = (15, 8))
sns.countplot(x="시군구명", data= kn20)
plt.title("20년도 경상남도 시군구별 매장수")
plt.ylabel("매장수")
plt.show()

plt.figure(figsize = (15, 8))
sns.countplot(x="시군구명", data= kn21)
plt.title("21년도 경상남도 시군구별 매장수")
plt.ylabel("매장수")
plt.show()

plt.figure(figsize = (15, 8))
sns.countplot(x="시군구명", data= kn22)
plt.title("22년도 경상남도 시군구별 매장수")
plt.ylabel("매장수")
plt.show()

# %% [markdown]
# ### 매출데이터(2019,2020)

# %%
sales = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/시도_산업중분류별_주요지표_20220731104916.csv",encoding='cp949')

# %%
sales.head()
# Out:
#    시도별       산업별        2019      2019.1       2019.2        2019.3  \
# 0  시도별       산업별  총 사업체수 (개)  총 종사자수 (명)  총 매출액 (백만원)  총 영업비용 (백만원)
# 1   전국       전산업     2771086     6443431    650424913     559431608
# 2   전국       제조업      355992     1176595    154005356     135161137
# 3   전국       건설업      114607      492457     51874146      48408378
# 4   전국  도매 및 소매업      891257     1870109    306428325     271182966
#
#          2019.4        2020      2020.1       2020.2        2020.3  \
# 0  총 영업이익 (백만원)  총 사업체수 (개)  총 종사자수 (명)  총 매출액 (백만원)  총 영업비용 (백만원)
# 1      90993305     2894360     5565987    660855744     602850680
# 2      18844219      369822     1095626    154323023     136295182
# 3       3465768      130307      387643     61362286      57249077
# 4      35245359      911339     1556299    302317398     283352962
#
#          2020.4
# 0  총 영업이익 (백만원)
# 1      58005064
# 2      18027841
# 3       4113209
# 4      18964436

# %%
sales.columns = ['시도별','산업별','2019총 사업체수(개)','2019총 종사자수(명)','2019총 매출액(백만원)','2019총 영업비용(백만원)','2019총 영업이익(백만원)','2020총 사업체수(개)','2020총 종사자수(명)','2020총 매출액(백만원)','2020총 영업비용(백만원)','2020총 영업이익(백만원)']

# %%
sales.head()
# Out:
#    시도별       산업별 2019총 사업체수(개) 2019총 종사자수(명) 2019총 매출액(백만원) 2019총 영업비용(백만원)  \
# 0  시도별       산업별    총 사업체수 (개)    총 종사자수 (명)    총 매출액 (백만원)    총 영업비용 (백만원)
# 1   전국       전산업       2771086       6443431      650424913       559431608
# 2   전국       제조업        355992       1176595      154005356       135161137
# 3   전국       건설업        114607        492457       51874146        48408378
# 4   전국  도매 및 소매업        891257       1870109      306428325       271182966
#
#   2019총 영업이익(백만원) 2020총 사업체수(개) 2020총 종사자수(명) 2020총 매출액(백만원) 2020총 영업비용(백만원)  \
# 0    총 영업이익 (백만원)    총 사업체수 (개)    총 종사자수 (명)    총 매출액 (백만원)    총 영업비용 (백만원)
# 1        90993305       2894360       5565987      660855744       602850680
# 2        18844219        369822       1095626      154323023       136295182
# 3         3465768        130307        387643       61362286        57249077
# 4        35245359        911339       1556299      302317398       283352962
#
#   2020총 영업이익(백만원)
# 0    총 영업이익 (백만원)
# ...

# %%
kn_sales = sales[sales['시도별']=='경상남도']
kn_sales
# Out:
#       시도별                     산업별 2019총 사업체수(개) 2019총 종사자수(명) 2019총 매출액(백만원)  \
# 193  경상남도                     전산업        199727        450676       41286606
# 194  경상남도                     제조업         29588         94395       12604359
# 195  경상남도                     건설업          8550         37938        3315080
# 196  경상남도                도매 및 소매업         59777        120508       17489799
# 197  경상남도               숙박 및 음식점업         53069        115680        5091341
# 198  경상남도                   정보통신업           486          1145          93625
# 199  경상남도                    부동산업          6122          8244         204522
# 200  경상남도              전문과학기술서비스업          2500          5156         322009
# 201  경상남도  사업시설관리, 사업지원 및 임대 서비스업          2892          7038         405418
# 202  경상남도                 교육 서비스업          9800         19002         500309
# 203  경상남도     예술, 스포츠 및 여가관련 서비스업          5771         10824         318247
# ...

# %%
kn_sales_all = kn_sales.iloc[[6,11,3,9,10,4],[1,4,9,6,11]]
kn_sales_all = kn_sales_all.transpose()
kn_sales_all.columns = ["부동산",	"생활서비스",	"소매",	"학문/교육",	"예술/스포츠/여가",	"숙박/음식점"]
kn_sales_all= kn_sales_all.drop(['산업별'])
kn_sales_all
# Out:
#                     부동산   생활서비스        소매   학문/교육 예술/스포츠/여가   숙박/음식점
# 2019총 매출액(백만원)   204522  941897  17489799  500309    318247  5091341
# 2020총 매출액(백만원)   268722  989655  17415231  467953    300909  5371870
# 2019총 영업이익(백만원)   49369  305672   2539918  218080    115639  1567906
# 2020총 영업이익(백만원)   66412  203839   1184132   99059     23298   943960

# %%
# 매출 지수를 통하여 매출액을 추정해줍니다.
# 예시) 2020년 <매출액 100만원> & <2020년 매출지수 100> & <2021년 매출지수 200> ---> <2021년 매출액 200만원>
# 매출지수가 없는 부동산은 변화 추세가 유지된다고 가정
kn_Sales_indic_2020 = [kn_sales_all["부동산"][1]/kn_sales_all["부동산"][0]*100, 106.43, 99.71, 101.64, 119.58, 89.88, 90.03]
Seoul_Sales_indic_2021 = [ kn_Sales_indic_2020[0]*kn_sales_all["부동산"][1]/kn_sales_all["부동산"][0], 126.85, 118.83, 138.92, 83.05, 72.71, 98.33]
Seoul_Sales_indic_2022 = [Seoul_Sales_indic_2021[0]*kn_sales_all["부동산"][1]/kn_sales_all["부동산"][0], 120.82, 125.65, 206.84, 109.58, 69.76, 133.08]

kn_sales_all = kn_sales_all.transpose()
kn_sales_all["총 매출액 (백만원, 2021)"] = [0] * len(kn_sales_all)
kn_sales_all["총 매출액 (백만원, 2022)"] = [0] * len(kn_sales_all)

for i in range(len(kn_sales_all)):
  kn_sales_all["총 매출액 (백만원, 2021)"][i] = kn_sales_all["총 매출액 (백만원, 2020)"][i] * Seoul_Sales_indic_2021[i] /  kn_Sales_indic_2020[i]
  kn_sales_all["총 매출액 (백만원, 2022)"][i] = kn_sales_all["총 매출액 (백만원, 2021)"][i] * Seoul_Sales_indic_2022[i] / Seoul_Sales_indic_2021[i]

kn_sales_all = kn_sales_all.transpose()
kn_sales_all["합계"] = [0,0,0,0]
kn_sales_all["합계"] = kn_sales_all[kn_sales_all.columns].sum(axis=1)

kn_sale_alls
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-18b4f2ab0108> in <module>()
#       2 # 예시) 2020년 <매출액 100만원> & <2020년 매출지수 100> & <2021년 매출지수 200> ---> <2021년 매출액 200만원>
#       3 # 매출지수가 없는 부동산은 변화 추세가 유지된다고 가정
# ----> 4 kn_Sales_indic_2020 = [kn_sales_all["부동산"][1]/kn_sales_all["부동산"][0]*100, 106.43, 99.71, 101.64, 119.58, 89.88, 90.03]
#       5 kn_Sales_indic_2021 = [ kn_Sales_indic_2020[0]*kn_sales_all["부동산"][1]/kn_sales_all["부동산"][0], 126.85, 118.83, 138.92, 83.05, 72.71, 98.33]
#       6 kn_Sales_indic_2022 = [kn_Sales_indic_2021[0]*kn_sales_all["부동산"][1]/kn_sales_all["부동산"][0], 120.82, 125.65, 206.84, 109.58, 69.76, 133.08]
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
kn_upso = table3.transpose()
kn_upso['숙박/음식점']= kn_upso['숙박']+kn_upso['음식']
kn_upso['예술/스포츠/여가'] = kn_upso['관광/여가/오락'] + kn_upso['스포츠']
kn_upso.drop(['All','관광/여가/오락','스포츠','숙박','음식'],axis=1,inplace=True)
kn_upso = kn_upso.iloc[:,[0,1,2,3,5,4]]
kn_upso
# Out:
# 상권업종대분류명    부동산  생활서비스     소매  학문/교육  예술/스포츠/여가  숙박/음식점
# 20년 총 업소수  4604  27817  55811  13496       4983   73426
# 21년 총 업소수  4155  24706  47757  10910       3771   69149
# 22년 총 업소수  4782  25304  47130  10604       5009   62964

# %%
kn_sales_upso = pd.concat([kn_upso,kn_sales_all])
kn_sales_upso = kn_sales_upso.transpose()
kn_sales_upso
# Out:
#           20년 총 업소수 21년 총 업소수 22년 총 업소수 2019총 매출액(백만원) 2020총 매출액(백만원)  \
# 부동산            4604      4155      4782         204522         268722
# 생활서비스         27817     24706     25304         941897         989655
# 소매            55811     47757     47130       17489799       17415231
# 학문/교육         13496     10910     10604         500309         467953
# 예술/스포츠/여가      4983      3771      5009         318247         300909
# 숙박/음식점        73426     69149     62964        5091341        5371870
#
#           2019총 영업이익(백만원) 2020총 영업이익(백만원)
# 부동산                 49369           66412
# 생활서비스              305672          203839
# 소매                2539918         1184132
# 학문/교육              218080           99059
# 예술/스포츠/여가          115639           23298
# 숙박/음식점            1567906          943960

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  - '도매 및 소매업' = 소매
#  - '숙박 및 음식점업'= 숙박 + 음식
#  - '부동산업' = 부동산
#  - '교육 서비스업'= 학문/교육
#  - '예술, 스포츠 및 여가관련 서비스업'= 스포츠, 관광/여가/오락
#  - '수리 및 기타 개인서비스업'=생활서비스

# %% [markdown]
# 관광업은 창원시에 가장 많았고, 음식은 김해시에 가장 많았다.

# %% [markdown]
# ### **경남 소결론**
# **업소수에 따른 결론**
# - 경남 지역에서 20-21 가장 많이 감소한 것은 관광/여가/오락이었다. 21-22 에 증가도 1%로 회복을 거의 못했다.
# - 두번째로 가장 많이 감소한 것은 학문/교육이었다.
# - 전체적 업종 수는 14% 감소했다.
# - 스포츠 업종은 폭발적으로 증가했다.
# - 부동산 업종은 20-21에는 감소세를 보였으나 21-22 더 큰 증가율을 보여 업소수가 오히려 더 많아졌다.
#
#
# 이를 통틀어 보았을 때 경남지역은 관광/여가/오락 업종과 학문/교육 업종의 지원이 더 필요하며, 부동산 업계와 스포츠업계는 지원을 줄여도 된다.
#
# **매출액에 따른 결론**
# - 부동산은 19-20 동안 매출액, 영업이익이 모두 증가했다.
# - 학문/교육, 예술/스포츠,여가는 19-20 동안 매출액, 영업이익 모두 감소했다.
# - 숙박/음식점은 19-20 영업이익은 큰 폭으로 줄었다.
#
# 따라서 경남시에서 부동산업계에 대한 지원을 줄이고, 예술/스포츠/여가 , 학문/교육 , 숙박/음식점에 대한 지원을 늘려야 한다.

# %% [markdown]
# ## 경북

# %% [markdown]
# ### 업종 대분류별 업소수

# %%
#2019년 상권업종대분류명
table4_kb = pd.pivot_table(data = kb19, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table4_kb.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       152917
# 음식         57087
# 소매         52064
# 생활서비스      24267
# 학문/교육       9687
# 숙박          3549
# 관광/여가/오락    3385
# 부동산         2807
# 스포츠           71

# %%
#2020년 상권업종대분류명
table0_kb = pd.pivot_table(data = kb20, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table0_kb.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       156549
# 음식         58368
# 소매         52943
# 생활서비스      25307
# 학문/교육       9845
# 숙박          3636
# 관광/여가/오락    3437
# 부동산         2900
# 스포츠          113

# %%
#2021년 상권업종대분류명
table1_kb = pd.pivot_table(data = kb21, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table1_kb.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       139311
# 음식         54618
# 소매         44484
# 생활서비스      22834
# 학문/교육       8153
# 숙박          3382
# 부동산         2797
# 관광/여가/오락    2529
# 스포츠          514

# %%
#2022년 상권업종대분류명
table2_kb = pd.pivot_table(data = kb22, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table2_kb.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       133941
# 음식         49090
# 소매         43363
# 생활서비스      22919
# 학문/교육       7744
# 숙박          3491
# 부동산         3285
# 관광/여가/오락    2599
# 스포츠         1450

# %%
table3_kb = pd.concat([table4_kn, table0_kb, table1_kb, table2_kb], axis = 1)
table3_kb.columns = ['19년 총 업소수','20년 총 업소수', '21년 총 업소수', '22년 총 업소수'] 
table3_kb.transpose()
# Out:
# 상권업종대분류명   관광/여가/오락   부동산  생활서비스     소매    숙박   스포츠     음식  학문/교육     All
# 19년 총 업소수      4835  4509  26397  55052  4156    56  67913  13371  176289
# 20년 총 업소수      3437  2900  25307  52943  3636   113  58368   9845  156549
# 21년 총 업소수      2529  2797  22834  44484  3382   514  54618   8153  139311
# 22년 총 업소수      2599  3285  22919  43363  3491  1450  49090   7744  133941

# %%
table_kb_all = table3_kb.transpose()['All']
table_kb_all
# Out:
# 19년 총 업소수    176289
# 20년 총 업소수    156549
# 21년 총 업소수    139311
# 22년 총 업소수    133941
# Name: All, dtype: int64

# %%
table3_kb_ori = pd.concat([table0_kb, table1_kb, table2_kb], axis = 1)
table3_kb_ori.columns = ['20년 총 업소수', '21년 총 업소수', '22년 총 업소수']
table3_kb_ori
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수
# 상권업종대분류명
# 관광/여가/오락       3437       2529       2599
# 부동산            2900       2797       3285
# 생활서비스         25307      22834      22919
# 소매            52943      44484      43363
# 숙박             3636       3382       3491
# 스포츠             113        514       1450
# 음식            58368      54618      49090
# 학문/교육          9845       8153       7744
# All          156549     139311     133941

# %%
table_kb_new = pd.concat([table0_kb, table1_kb, table2_kb], axis = 1)
table_kb_new.columns = ['20년 총 업소수', '21년 총 업소수', '22년 총 업소수']
table_kb_new
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수
# 상권업종대분류명
# 관광/여가/오락       3437       2529       2599
# 부동산            2900       2797       3285
# 생활서비스         25307      22834      22919
# 소매            52943      44484      43363
# 숙박             3636       3382       3491
# 스포츠             113        514       1450
# 음식            58368      54618      49090
# 학문/교육          9845       8153       7744
# All          156549     139311     133941

# %%
rate_20_21 = (table3_kb_ori['21년 총 업소수']-table3_kb_ori['20년 총 업소수'])/table3_kb_ori['20년 총 업소수']*100
rate_21_22 = (table3_kb_ori['22년 총 업소수']-table3_kb_ori['21년 총 업소수'])/table3_kb_ori['21년 총 업소수']*100
rate_20_21.name = '20-21 증감률'
rate_21_22.name = '21-22 증감률'

# %%
#20,21,22 증감률 표
kb_rate = pd.concat([table3_kb_ori,rate_20_21,rate_21_22],axis=1)
kb_rate
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수   20-21 증감률   21-22 증감률
# 상권업종대분류명
# 관광/여가/오락       3437       2529       2599  -26.418388    2.767892
# 부동산            2900       2797       3285   -3.551724   17.447265
# 생활서비스         25307      22834      22919   -9.772000    0.372252
# 소매            52943      44484      43363  -15.977561   -2.520007
# 숙박             3636       3382       3491   -6.985699    3.222945
# 스포츠             113        514       1450  354.867257  182.101167
# 음식            58368      54618      49090   -6.424753  -10.121205
# 학문/교육          9845       8153       7744  -17.186389   -5.016558
# All          156549     139311     133941  -11.011249   -3.854685

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **업소수에 따른 결론**
# - 20-21에 업소수가 가장 많이 감소한 것은 관광/여가/오락이었다.
# - 부동산은 오히려 20보다 22에 증가했다.

# %%
t_20 = table3['20년 총 업소수']
t_21 = table3['21년 총 업소수']
t_22 = table3['22년 총 업소수']

sizes_20 = [t_20[0],t_20[1],t_20[2],t_20[3],t_20[4],t_20[5],t_20[6],t_20[7]]
sizes_21 = [t_21[0],t_21[1],t_21[2],t_21[3],t_21[4],t_21[5],t_21[6],t_21[7]]
sizes_22 = [t_22[0],t_22[1],t_22[2],t_22[3],t_22[4],t_22[5],t_22[6],t_22[7]]

labels = ['관광/여가/오락','부동산','생활서비스','소매','숙박','스포츠','음식','학문/교육']

plt.subplot(131)
plt.pie(sizes_20,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10}
        )
plt.axis('equal')
plt.title("2020 경북")

plt.subplot(132)
plt.pie(sizes_21,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10})
plt.axis('equal')
plt.title("2021 경북")


plt.subplot(133)
plt.pie(sizes_22,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10})
plt.axis('equal')
plt.title("2022 경북")

plt.show()

# %% [markdown]
# ### 업소 커버리지

# %%
kb_pop
# Out:
#                2019     2020     2021  2022.06
# 행정구역(시군구)별
# 경상북도        2665836  2639422  2626609  2613963

# %%
table3_kb_ori['2020인구수'] = 2639422
table3_kb_ori['2021인구수'] = 2626609
table3_kb_ori['2022인구수'] = 2613963

table3_kb_ori
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수  2020인구수  2021인구수  2022인구수
# 상권업종대분류명
# 관광/여가/오락       3437       2529       2599  2639422  2626609  2613963
# 부동산            2900       2797       3285  2639422  2626609  2613963
# 생활서비스         25307      22834      22919  2639422  2626609  2613963
# 소매            52943      44484      43363  2639422  2626609  2613963
# 숙박             3636       3382       3491  2639422  2626609  2613963
# 스포츠             113        514       1450  2639422  2626609  2613963
# 음식            58368      54618      49090  2639422  2626609  2613963
# 학문/교육          9845       8153       7744  2639422  2626609  2613963
# All          156549     139311     133941  2639422  2626609  2613963

# %%
# 인구 수 당 커버리지 : 업소 당 얼마나 많은 인구수를 감당할 수 있는지 (인구수/업소수)
table3_kb_ori['2020커버리지'] = table3_kb_ori['2020인구수']/table3_kb_ori['20년 총 업소수']
table3_kb_ori['2021커버리지'] = table3_kb_ori['2021인구수']/table3_kb_ori['21년 총 업소수']
table3_kb_ori['2022커버리지'] = table3_kb_ori['2022인구수']/table3_kb_ori['22년 총 업소수']


table3_kb_ori
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수  2020인구수  2021인구수  2022인구수  \
# 상권업종대분류명
# 관광/여가/오락       3437       2529       2599  2639422  2626609  2613963
# 부동산            2900       2797       3285  2639422  2626609  2613963
# 생활서비스         25307      22834      22919  2639422  2626609  2613963
# 소매            52943      44484      43363  2639422  2626609  2613963
# 숙박             3636       3382       3491  2639422  2626609  2613963
# 스포츠             113        514       1450  2639422  2626609  2613963
# 음식            58368      54618      49090  2639422  2626609  2613963
# 학문/교육          9845       8153       7744  2639422  2626609  2613963
# All          156549     139311     133941  2639422  2626609  2613963
#
#               2020커버리지     2021커버리지     2022커버리지
# 상권업종대분류명
# 관광/여가/오락    767.943555  1038.595888  1005.757214
# 부동산         910.145517   939.080801   795.726941
# 생활서비스       104.296124   115.030612   114.052227
# 소매           49.854032    59.046151    60.280954
# ...

# %% [markdown]
# ### 경북 지역별 업소수

# %%
#2022 경북 시별 업소수
pivot_kb = pd.pivot_table(data = kb22, index = "시군구명", columns = "상권업종대분류명", values = "상가업소번호", aggfunc = ['count'], 
                              fill_value = 0, margins=True, margins_name="합계")
pivot_kb
# Out:
#             count
# 상권업종대분류명 관광/여가/오락   부동산  생활서비스     소매    숙박   스포츠     음식 학문/교육      합계
# 시군구명
# 경산시           230   442   2239   3818    78   153   4449   767   12176
# 경주시           305   356   2636   5142   818   141   6527   957   16882
# 고령군            20    31    213    614    24     8    474    43    1427
# 구미시           483   635   3419   5203   191   243   6582  1518   18274
# 군위군            17    31    150    304    25    10    409    23     969
# 김천시           107   110   1076   1825   153    70   2138   330    5809
# 문경시            77    77    659   1389   168    58   1435   187    4050
# 봉화군            16    19    192    461    56    20    510    26    1300
# 상주시            62    69    876   1926    74    47   1657   240    4951
# 성주군            36    57    300    722    69    17    886    74    2161
# 안동시           182   146   1650   3320   199   101   3221   574    9393
# 영덕군            36    33    334    897   207    14   1240    50    2811
# ...

# %%
plt.figure(figsize = (15, 8))
sns.countplot(x="시군구명", data= kb20)
plt.title("20년도 경상북도 시군구별 매장수")
plt.ylabel("매장수")
plt.show()

plt.figure(figsize = (15, 8))
sns.countplot(x="시군구명", data= kb21)
plt.title("21년도 경상북도 시군구별 매장수")
plt.ylabel("매장수")
plt.show()

plt.figure(figsize = (15, 8))
sns.countplot(x="시군구명", data= kb22)
plt.title("22년도 경상북도 시군구별 매장수")
plt.ylabel("매장수")
plt.show()

# %% [markdown]
# - 경북에서 업소수가 가장 많은 것은 경주시, 구미시, 포항시이다.

# %% [markdown]
# ### 매출데이터

# %%
kb_sales = sales[sales['시도별']=='경상북도']
kb_sales
# Out:
#       시도별                     산업별 2019총 사업체수(개) 2019총 종사자수(명) 2019총 매출액(백만원)  \
# 181  경상북도                     전산업        165719        366562       35054287
# 182  경상북도                     제조업         23481         75840       10906751
# 183  경상북도                     건설업          8581         36987        3209865
# 184  경상북도                도매 및 소매업         51336         98792       14901471
# 185  경상북도               숙박 및 음식점업         44385         92936        3968252
# 186  경상북도                   정보통신업           481           976          73666
# 187  경상북도                    부동산업          3934          5562         150130
# 188  경상북도              전문과학기술서비스업          1862          3778         261654
# 189  경상북도  사업시설관리, 사업지원 및 임대 서비스업          2347          5430         301759
# 190  경상북도                 교육 서비스업          6658         12324         299197
# 191  경상북도     예술, 스포츠 및 여가관련 서비스업          5081          9102         253948
# ...

# %%
kb_sales_all = kb_sales.iloc[[6,11,3,9,10,4],[1,4,9,6,11]]
kb_sales_all = kb_sales_all.transpose()
kb_sales_all.columns = ["부동산",	"생활서비스",	"소매",	"학문/교육",	"예술/스포츠/여가",	"숙박/음식점"]
kb_sales_all= kb_sales_all.drop(['산업별'])
kb_sales_all
# Out:
#                     부동산   생활서비스        소매   학문/교육 예술/스포츠/여가   숙박/음식점
# 2019총 매출액(백만원)   150130  727595  14901471  299197    253948  3968252
# 2020총 매출액(백만원)   185937  748196  14800184  264316    229382  3970926
# 2019총 영업이익(백만원)   59492  239887   2140479  125619     98488  1102741
# 2020총 영업이익(백만원)   24354  170345   1080629   42999     34805   370670

# %%
kb_upso = table3_kb.transpose()
kb_upso['숙박/음식점']= kb_upso['숙박']+kb_upso['음식']
kb_upso['예술/스포츠/여가'] = kb_upso['관광/여가/오락'] + kb_upso['스포츠']
kb_upso.drop(['All','관광/여가/오락','스포츠','숙박','음식'],axis=1,inplace=True)
kb_upso = kb_upso.iloc[:,[0,1,2,3,5,4]]
kb_upso
# Out:
# 상권업종대분류명    부동산  생활서비스     소매  학문/교육  예술/스포츠/여가  숙박/음식점
# 20년 총 업소수  2900  25307  52943   9845       3550   62004
# 21년 총 업소수  2797  22834  44484   8153       3043   58000
# 22년 총 업소수  3285  22919  43363   7744       4049   52581

# %%
kb_sales_upso = pd.concat([kb_upso,kb_sales_all])
kb_sales_upso = kb_sales_upso.transpose()
kb_sales_upso
# Out:
#           20년 총 업소수 21년 총 업소수 22년 총 업소수 2019총 매출액(백만원) 2020총 매출액(백만원)  \
# 부동산            2900      2797      3285         150130         185937
# 생활서비스         25307     22834     22919         727595         748196
# 소매            52943     44484     43363       14901471       14800184
# 학문/교육          9845      8153      7744         299197         264316
# 예술/스포츠/여가      3550      3043      4049         253948         229382
# 숙박/음식점        62004     58000     52581        3968252        3970926
#
#           2019총 영업이익(백만원) 2020총 영업이익(백만원)
# 부동산                 59492           24354
# 생활서비스              239887          170345
# 소매                2140479         1080629
# 학문/교육              125619           42999
# 예술/스포츠/여가           98488           34805
# 숙박/음식점            1102741          370670

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 경북 소결론
# **업소수에 따른 결론**
# - 20-21에 업소수가 가장 많이 감소한 것은 관광/여가/오락이었다.
# - 부동산은 오히려 20보다 22에 증가했다.
#
# **매출액에 따른 결론**
# - 19-20 영업이익은 모든 업종에서 줄었다.
# - 특히 학문, 예술/스포츠/여가, 숙박/음식점이 66%나 감소했다. 코로나 때문에 관광업이 타격을 받으며 같이 영업이익이 감소한 것으로 보인다.
#
# 따라서 경북지역에는 예술/스포츠/여가, 숙박/음식점에 지원을 더 많이 해주어야 한다.

# %% [markdown]
# ## 부산

# %% [markdown]
# ### 업종 대분류별 업소수

# %%
#2019년 상권업종대분류명
table4_bs = pd.pivot_table(data = bs19, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table4_bs.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       157516
# 소매         52808
# 음식         52028
# 생활서비스      29760
# 학문/교육      10892
# 부동산         5030
# 관광/여가/오락    4705
# 숙박          2193
# 스포츠          100

# %%
#2020년 상권업종대분류명
table0_bs = pd.pivot_table(data = bs20, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table0_bs.sort_values(by='상가업소번호',ascending=False)
#2021년 상권업종대분류명
table1_bs = pd.pivot_table(data = bs21, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table1_bs.sort_values(by='상가업소번호',ascending=False)
#2022년 상권업종대분류명
table2_bs = pd.pivot_table(data = bs22, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table2_bs.sort_values(by='상가업소번호',ascending=False)

table3_bs = pd.concat([table4_bs,table0_bs, table1_bs, table2_bs], axis = 1)
table3_bs.columns = ['19년 총 업소수','20년 총 업소수', '21년 총 업소수', '22년 총 업소수']
table3_bs
# Out:
#           19년 총 업소수  20년 총 업소수  21년 총 업소수  22년 총 업소수
# 상권업종대분류명
# 관광/여가/오락       4705       4752       2857       3204
# 부동산            5030       5235       4515       5969
# 생활서비스         29760      30924      23722      26089
# 소매            52808      53430      44740      49702
# 숙박             2193       2261       1665       1665
# 스포츠             100        131        690       1957
# 음식            52028      53116      49866      49502
# 학문/교육         10892      10994       8462       9711
# All          157516     160843     136517     147799

# %%
table_bs_new =  pd.concat([table0_bs, table1_bs, table2_bs], axis = 1)
table_bs_new.columns = ['20년 총 업소수', '21년 총 업소수', '22년 총 업소수']

# %%
table3_bs.transpose()
# Out:
# 상권업종대분류명   관광/여가/오락   부동산  생활서비스     소매    숙박   스포츠     음식  학문/교육     All
# 19년 총 업소수      4705  5030  29760  52808  2193   100  52028  10892  157516
# 20년 총 업소수      4752  5235  30924  53430  2261   131  53116  10994  160843
# 21년 총 업소수      2857  4515  23722  44740  1665   690  49866   8462  136517
# 22년 총 업소수      3204  5969  26089  49702  1665  1957  49502   9711  147799

# %%
table_bs_all= table3_bs.transpose()['All']
table_bs_all
# Out:
# 19년 총 업소수    157516
# 20년 총 업소수    160843
# 21년 총 업소수    136517
# 22년 총 업소수    147799
# Name: All, dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **업종수 결론**
# - 20-21에 스포츠업종을 제외한 모든 업종에서 감소했다.
# - 특히 관광/여가/오락이 40% 감소했다.
# - 21-22 에는 대부분의 업종에서 증가세를 보였다.
# - 부동산 업종은 20년에 비해 22년 더 증가했다.

# %%
t_20 = table3['20년 총 업소수']
t_21 = table3['21년 총 업소수']
t_22 = table3['22년 총 업소수']

sizes_20 = [t_20[0],t_20[1],t_20[2],t_20[3],t_20[4],t_20[5],t_20[6],t_20[7]]
sizes_21 = [t_21[0],t_21[1],t_21[2],t_21[3],t_21[4],t_21[5],t_21[6],t_21[7]]
sizes_22 = [t_22[0],t_22[1],t_22[2],t_22[3],t_22[4],t_22[5],t_22[6],t_22[7]]

labels = ['관광/여가/오락','부동산','생활서비스','소매','숙박','스포츠','음식','학문/교육']

plt.subplot(131)
plt.pie(sizes_20,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10}
        )
plt.axis('equal')
plt.title("2020 부산")

plt.subplot(132)
plt.pie(sizes_21,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10})
plt.axis('equal')
plt.title("2021 부산")


plt.subplot(133)
plt.pie(sizes_22,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10})
plt.axis('equal')
plt.title("2022 부산")

plt.show()

# %% [markdown]
# ### 업소 커버리지

# %%
bs_pop
# Out:
#                2019     2020     2021  2022.06
# 행정구역(시군구)별
# 부산광역시       3413841  3391946  3350380  3336737

# %%
table3_bs_1 = table3_bs

# %%
table3_bs_1['2020인구수'] = 3391946
table3_bs_1['2021인구수'] = 3350380
table3_bs_1['2022인구수'] = 3336737

table3_bs_1
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수  2020인구수  2021인구수  2022인구수
# 상권업종대분류명
# 관광/여가/오락       4752       2857       3204  3391946  3350380  3336737
# 부동산            5235       4515       5969  3391946  3350380  3336737
# 생활서비스         30924      23722      26089  3391946  3350380  3336737
# 소매            53430      44740      49702  3391946  3350380  3336737
# 숙박             2261       1665       1665  3391946  3350380  3336737
# 스포츠             131        690       1957  3391946  3350380  3336737
# 음식            53116      49866      49502  3391946  3350380  3336737
# 학문/교육         10994       8462       9711  3391946  3350380  3336737
# All          160843     136517     147799  3391946  3350380  3336737

# %%
# 인구 수 당 커버리지 : 업소 당 얼마나 많은 인구수를 감당할 수 있는지 (인구수/업소수)
table3_bs_1['2020커버리지'] = table3_bs_1['2020인구수']/table3_bs_1['20년 총 업소수']
table3_bs_1['2021커버리지'] = table3_bs_1['2021인구수']/table3_bs_1['21년 총 업소수']
table3_bs_1['2022커버리지'] = table3_bs_1['2022인구수']/table3_bs_1['22년 총 업소수']


table3_bs_1
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수  2020인구수  2021인구수  2022인구수  \
# 상권업종대분류명
# 관광/여가/오락       4752       2857       3204  3391946  3350380  3336737
# 부동산            5235       4515       5969  3391946  3350380  3336737
# 생활서비스         30924      23722      26089  3391946  3350380  3336737
# 소매            53430      44740      49702  3391946  3350380  3336737
# 숙박             2261       1665       1665  3391946  3350380  3336737
# 스포츠             131        690       1957  3391946  3350380  3336737
# 음식            53116      49866      49502  3391946  3350380  3336737
# 학문/교육         10994       8462       9711  3391946  3350380  3336737
# All          160843     136517     147799  3391946  3350380  3336737
#
#               2020커버리지     2021커버리지     2022커버리지
# 상권업종대분류명
# 관광/여가/오락    713.793350  1172.691635  1041.428527
# 부동산         647.936199   742.055371   559.011057
# 생활서비스       109.686522   141.235140   127.898233
# 소매           63.483923    74.885561    67.134864
# ...

# %% [markdown]
# ### 부산 지역별 데이터

# %%
#2022 부산 시별 업소수
pivot_bs = pd.pivot_table(data = bs22, index = "시군구명", columns = "상권업종대분류명", values = "상가업소번호", aggfunc = ['count'], 
                              fill_value = 0, margins=True, margins_name="합계")
pivot_bs
# Out:
#             count
# 상권업종대분류명 관광/여가/오락   부동산  생활서비스     소매    숙박   스포츠     음식 학문/교육      합계
# 시군구명
# 강서구            96   556   1074   2300    57   128   2602   426    7239
# 금정구           250   354   1833   2989    67   139   3294   695    9621
# 기장군           130   384   1129   2316    90    89   3107   541    7786
# 남구            230   432   1977   2949    51   137   3442   789   10007
# 동구             82   133    811   2936   125    51   1675   137    5950
# 동래구           258   441   1963   3235   102   146   3496   866   10507
# 부산진구          358   682   3244   6956   183   207   6074  1020   18724
# 북구            232   293   1598   2537    86   120   2923   682    8471
# 사상구           264   303   1732   3597    95   134   2681   438    9244
# 사하구           344   446   2340   3977    72   161   3859  1078   12277
# 서구             79   104    679   1190    69    44   1457   238    3860
# 수영구           178   370   1550   2569   115   117   3142   638    8679
# ...

# %% [markdown]
# 남구, 동래구, 부산진구, 사하구, 해운대구 가 업소수가 가장 많다.

# %% [markdown]
# ### 매출데이터

# %%
bs_sales = sales[sales['시도별']=='부산광역시']
bs_sales
# Out:
#       시도별                     산업별 2019총 사업체수(개) 2019총 종사자수(명) 2019총 매출액(백만원)  \
# 25  부산광역시                     전산업        197585        451743       43065436
# 26  부산광역시                     제조업         25970         80027        9142385
# 27  부산광역시                     건설업          7005         30684        2647794
# 28  부산광역시                도매 및 소매업         69387        145130       23041235
# 29  부산광역시               숙박 및 음식점업         43959        103846        4845720
# 30  부산광역시                   정보통신업           883          2000         166908
# 31  부산광역시                    부동산업          7758         13194         578637
# 32  부산광역시              전문과학기술서비스업          2906          6122         479374
# 33  부산광역시  사업시설관리, 사업지원 및 임대 서비스업          3058          7402         377013
# 34  부산광역시                 교육 서비스업          9200         18571         514747
# 35  부산광역시     예술, 스포츠 및 여가관련 서비스업          5596         11217         352808
# ...

# %%
bs_sales_all = bs_sales.iloc[[6,11,3,9,10,4],[1,4,9,6,11]]
bs_sales_all = bs_sales_all.transpose()
bs_sales_all.columns = ["부동산",	"생활서비스",	"소매",	"학문/교육",	"예술/스포츠/여가",	"숙박/음식점"]
bs_sales_all= bs_sales_all.drop(['산업별'])
bs_sales_all
# Out:
#                     부동산   생활서비스        소매   학문/교육 예술/스포츠/여가   숙박/음식점
# 2019총 매출액(백만원)   578637  918815  23041235  514747    352808  4845720
# 2020총 매출액(백만원)   681176  967885  22133732  495345    322884  5035681
# 2019총 영업이익(백만원)  192826  294821   2610676  168153    101271  1299023
# 2020총 영업이익(백만원)  166412  222372   1599239   85652      5224   441515

# %%
bs_upso = table3_bs.transpose()
bs_upso['숙박/음식점']= bs_upso['숙박']+bs_upso['음식']
bs_upso['예술/스포츠/여가'] = bs_upso['관광/여가/오락'] + bs_upso['스포츠']
bs_upso.drop(['All','관광/여가/오락','스포츠','숙박','음식'],axis=1,inplace=True)
bs_upso = bs_upso.iloc[:,[0,1,2,3,5,4]]
bs_upso
# Out:
# 상권업종대분류명    부동산  생활서비스     소매  학문/교육  예술/스포츠/여가  숙박/음식점
# 20년 총 업소수  5235  30924  53430  10994       4883   55377
# 21년 총 업소수  4515  23722  44740   8462       3547   51531
# 22년 총 업소수  5969  26089  49702   9711       5161   51167

# %%
bs_sales_upso = pd.concat([bs_upso,bs_sales_all])
bs_sales_upso = bs_sales_upso.transpose()
bs_sales_upso
# Out:
#           20년 총 업소수 21년 총 업소수 22년 총 업소수 2019총 매출액(백만원) 2020총 매출액(백만원)  \
# 부동산            5235      4515      5969         578637         681176
# 생활서비스         30924     23722     26089         918815         967885
# 소매            53430     44740     49702       23041235       22133732
# 학문/교육         10994      8462      9711         514747         495345
# 예술/스포츠/여가      4883      3547      5161         352808         322884
# 숙박/음식점        55377     51531     51167        4845720        5035681
#
#           2019총 영업이익(백만원) 2020총 영업이익(백만원)
# 부동산                192826          166412
# 생활서비스              294821          222372
# 소매                2610676         1599239
# 학문/교육              168153           85652
# 예술/스포츠/여가          101271            5224
# 숙박/음식점            1299023          441515

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 부산 소결론
# **업종수 결론**
# - 20-21에 스포츠업종을 제외한 모든 업종에서 감소했다.
# - 특히 관광/여가/오락이 40% 감소했다.
# - 21-22 에는 대부분의 업종에서 증가세를 보였다.
# - 부동산 업종은 20년에 비해 22년 더 증가했다.
#
# **매출 결론**
# - 19-20에는 모든 업종에서 영업이익이 감소했는데, 특히 예술/스포츠/여가 영업이익이 95% 감소했다.
#
# 부산에서도 부동산 업종에 대한 지원을 줄이고,특히 관광/여가/오락에 대한 지원을 늘리는 것이 합당해 보인다.

# %% [markdown]
# ## 울산

# %% [markdown]
# ### 업종 대분류별 업소수

# %%
#2019년 상권업종대분류명
table4_us = pd.pivot_table(data = us19, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table4_us.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All        59371
# 음식         22157
# 소매         18344
# 생활서비스       9014
# 학문/교육       5229
# 관광/여가/오락    2120
# 부동산         1668
# 숙박           826
# 스포츠           13

# %%
#2020년 상권업종대분류명
table0_us = pd.pivot_table(data = us20, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table0_us.sort_values(by='상가업소번호',ascending=False)
#2021년 상권업종대분류명
table1_us = pd.pivot_table(data = us21, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table1_us.sort_values(by='상가업소번호',ascending=False)
#2022년 상권업종대분류명
table2_us = pd.pivot_table(data = us22, index = "상권업종대분류명", values="상가업소번호", aggfunc = "count", margins=True)
table2_us.sort_values(by='상가업소번호',ascending=False)

table3_us = pd.concat([table4_us,table0_us, table1_us, table2_us], axis = 1)
table3_us_ori = pd.concat([table4_us, table0_us, table1_us, table2_us], axis = 1) #변경을 안가하는 dataframe 

table3_us.columns = ['19년 총 업소수','20년 총 업소수', '21년 총 업소수', '22년 총 업소수']
table3_us
# Out:
#           19년 총 업소수  20년 총 업소수  21년 총 업소수  22년 총 업소수
# 상권업종대분류명
# 관광/여가/오락       2120       2128       1112       1267
# 부동산            1668       1713       1226       1560
# 생활서비스          9014       9496       7626       8119
# 소매            18344      18567      12237      12836
# 숙박              826        840        641        643
# 스포츠              13         15        185        551
# 음식            22157      22617      18390      17435
# 학문/교육          5229       5268       3611       3859
# All           59371      60644      45028      46270

# %%
table_us_new = pd.concat([table0_us, table1_us, table2_us], axis = 1)
table_us_new.columns = ['20년 총 업소수', '21년 총 업소수', '22년 총 업소수']

# %%
table3_us.transpose()
# Out:
# 상권업종대분류명   관광/여가/오락   부동산  생활서비스     소매   숙박  스포츠     음식  학문/교육    All
# 19년 총 업소수      2120  1668   9014  18344  826   13  22157   5229  59371
# 20년 총 업소수      2128  1713   9496  18567  840   15  22617   5268  60644
# 21년 총 업소수      1112  1226   7626  12237  641  185  18390   3611  45028
# 22년 총 업소수      1267  1560   8119  12836  643  551  17435   3859  46270

# %%
table_us_all = table3_us.transpose()['All']
table_us_all
# Out:
# 19년 총 업소수    59371
# 20년 총 업소수    60644
# 21년 총 업소수    45028
# 22년 총 업소수    46270
# Name: All, dtype: int64

# %% [markdown]
# ![스크린샷 2022-07-30 오전 9.11.50.png](data:image/png;base64,...)

# %% [markdown]
# **업종별 결론**
# - 20-21에 관광/여가/오락, 소매, 학문/교육 업종수가 크게 감소했다.

# %%
t_20 = table3_us['20년 총 업소수']
t_21 = table3_us['21년 총 업소수']
t_22 = table3_us['22년 총 업소수']

sizes_20 = [t_20[0],t_20[1],t_20[2],t_20[3],t_20[4],t_20[5],t_20[6],t_20[7]]
sizes_21 = [t_21[0],t_21[1],t_21[2],t_21[3],t_21[4],t_21[5],t_21[6],t_21[7]]
sizes_22 = [t_22[0],t_22[1],t_22[2],t_22[3],t_22[4],t_22[5],t_22[6],t_22[7]]

labels = ['관광/여가/오락','부동산','생활서비스','소매','숙박','스포츠','음식','학문/교육']

plt.subplot(131)
plt.pie(sizes_20,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10}
        )
plt.axis('equal')
plt.title("2020 울산")

plt.subplot(132)
plt.pie(sizes_21,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10})
plt.axis('equal')
plt.title("2021 울산")


plt.subplot(133)
plt.pie(sizes_22,
        labels = labels,
        autopct = "%1.2f%%", # 우리가 부여한 숫자(sizes)를 알아서 퍼센트로 변환. 그 퍼센트의 소숫점 자릿수를 지정.
        shadow = True,
        startangle = 90, # 시작 각도
        textprops = {'fontsize':10})
plt.axis('equal')
plt.title("2022 울산")

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44305 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# ### 울산 지역별 데이터

# %%
#2022 울산 시별 업소수
pivot_us = pd.pivot_table(data = us22, index = "시군구명", columns = "상권업종대분류명", values = "상가업소번호", aggfunc = ['count'], 
                              fill_value = 0, margins=True, margins_name="합계")
pivot_us
# Out:
#             count
# 상권업종대분류명 관광/여가/오락   부동산 생활서비스     소매   숙박  스포츠     음식 학문/교육     합계
# 시군구명
# 남구            543   701  3429   5021  247  213   5923  1527  17604
# 동구            145    83   696   1145   60   57   2007   420   4613
# 북구            169   217  1056   1778   58  106   2774   677   6835
# 울주군           198   308  1331   2112  199   88   3753   592   8581
# 중구            212   251  1607   2780   79   87   2978   643   8637
# 합계           1267  1560  8119  12836  643  551  17435  3859  46270

# %% [markdown]
# - 울산에서는  남구에서 업소수가 가장 많지만,나머지 구에서는  대체로 비슷한 분포를 보인다.

# %% [markdown]
# ### 매출데이터

# %%
us_sales = sales[sales['시도별']=='울산광역시']
us_sales
# Out:
#       시도별                     산업별 2019총 사업체수(개) 2019총 종사자수(명) 2019총 매출액(백만원)  \
# 85  울산광역시                     전산업         59371        130454       11476920
# 86  울산광역시                     제조업          5448         16566        2174130
# 87  울산광역시                     건설업          2580         10873        1113658
# 88  울산광역시                도매 및 소매업         17825         37240        5384290
# 89  울산광역시               숙박 및 음식점업         16194         35656        1708780
# 90  울산광역시                   정보통신업           166           413          30032
# 91  울산광역시                    부동산업          2092          3223         111422
# 92  울산광역시              전문과학기술서비스업           842          1701         120430
# 93  울산광역시  사업시설관리, 사업지원 및 임대 서비스업           937          2554         142727
# 94  울산광역시                 교육 서비스업          3594          7344         225943
# 95  울산광역시     예술, 스포츠 및 여가관련 서비스업          2501          4504         145174
# ...

# %%
us_sales_all = us_sales.iloc[[6,11,3,9,10,4],[1,4,9,6,11]]
us_sales_all = us_sales_all.transpose()
us_sales_all.columns = ["부동산",	"생활서비스",	"소매",	"학문/교육",	"예술/스포츠/여가",	"숙박/음식점"]
us_sales_all= us_sales_all.drop(['산업별'])
us_sales_all
# Out:
#                     부동산   생활서비스       소매   학문/교육 예술/스포츠/여가   숙박/음식점
# 2019총 매출액(백만원)   111422  320333  5384290  225943    145174  1708780
# 2020총 매출액(백만원)   133319  338742  5360057  209066    126536  1795541
# 2019총 영업이익(백만원)   13243  126022   591878   81613     51952   444750
# 2020총 영업이익(백만원)   27847   69566   349069   56297     13594   328214

# %%
us_upso = table3_us.transpose()
us_upso['숙박/음식점']= us_upso['숙박']+us_upso['음식']
us_upso['예술/스포츠/여가'] = us_upso['관광/여가/오락'] + us_upso['스포츠']
us_upso.drop(['All','관광/여가/오락','스포츠','숙박','음식'],axis=1,inplace=True)
us_upso = us_upso.iloc[:,[0,1,2,3,5,4]]
us_upso
# Out:
# 상권업종대분류명    부동산  생활서비스     소매  학문/교육  예술/스포츠/여가  숙박/음식점
# 20년 총 업소수  1713   9496  18567   5268       2143   23457
# 21년 총 업소수  1226   7626  12237   3611       1297   19031
# 22년 총 업소수  1560   8119  12836   3859       1818   18078

# %%
us_sales_upso = pd.concat([us_upso,us_sales_all])
us_sales_upso = us_sales_upso.transpose()
us_sales_upso
# Out:
#           20년 총 업소수 21년 총 업소수 22년 총 업소수 2019총 매출액(백만원) 2020총 매출액(백만원)  \
# 부동산            1713      1226      1560         111422         133319
# 생활서비스          9496      7626      8119         320333         338742
# 소매            18567     12237     12836        5384290        5360057
# 학문/교육          5268      3611      3859         225943         209066
# 예술/스포츠/여가      2143      1297      1818         145174         126536
# 숙박/음식점        23457     19031     18078        1708780        1795541
#
#           2019총 영업이익(백만원) 2020총 영업이익(백만원)
# 부동산                 13243           27847
# 생활서비스              126022           69566
# 소매                 591878          349069
# 학문/교육               81613           56297
# 예술/스포츠/여가           51952           13594
# 숙박/음식점             444750          328214

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 울산 소결론
# **업종별 결론**
# - 20-21에 관광/여가/오락, 소매, 학문/교육 업종수가 크게 감소했다.
#
# **매출 결론**
# - 19-20에 부동산만 영업 이익이 증가했다.
# - 특히 예술/스포츠/여가 업종이 19-20 코로나의 영향을 받아 영업이익이 감소했다.

# %% [markdown]
# ## 결론

# %% [markdown]
# **지역별 특징**
#
# - 경남: 경남지역은 관광/여가/오락 업종과 학문/교육 업종의 지원이 더 필요하며, 부동산 업계와 스포츠업계는 지원을 줄여도 된다. 20->22 동안 총 업소수는 14%감소함
#
# - 경북: 경북지역에는 예술/스포츠/여가, 숙박/음식점에 지원을 더 많이 해주어야 한다. 20->22 동안 총 업소수는 15% 감소
#
# - 부산:부동산 업종에 대한 지원을 줄이고,특히 관광/여가/오락에 대한 지원을 늘려야 한다. 20->22 동안 총 업소수는 7% 감소
#
# - 울산: 부동산 업종에 대한 지원을 줄이고, 관광/여가/오락과 학문/교육에 대한 지원을 늘려야 한다. 20->22 동안 총 업소수는 23% 감소
#
# **업종별 특징**
# - 관광/여가/오락: 모든 지역에서 업소수가 줄었다.
# - 부동산: 지원을 줄여도 된다. 업소수/ 영업이익이 19->22 증가 OR 그대로
# - 생활서비스
# - 소매
# - 학문/교육: 대체로 감소하는 지역이 다수
# - 예술/스포츠/여가: 스포츠업종의 매장수는 크게 증가함
# - 숙박/음식점: 관광업의 타격이 큰 지역(부산)에서 특히 지원을 많이 해야함

# %% [markdown]
# # 시각화 그래프

# %% [markdown]
# ## 지역별 매장 수 변화

# %%
table_kn_all.drop('19년 총 업소수',axis=0,inplace=True)
table_kb_all.drop('19년 총 업소수',axis=0,inplace=True)
table_us_all.drop('19년 총 업소수',axis=0,inplace=True)
table_bs_all.drop('19년 총 업소수',axis=0,inplace=True)

# %%
table_kn_all = pd.DataFrame(table_kn_all)
table_kn_all['연도']=[2020,2021,2022]
table_kn_all
# Out:
#               All    연도
# 20년 총 업소수  180137  2020
# 21년 총 업소수  160448  2021
# 22년 총 업소수  155793  2022

# %%
table_kb_all
# Out:
#               All    연도
# 20년 총 업소수  156549  2020
# 21년 총 업소수  139311  2021
# 22년 총 업소수  133941  2022

# %%
table_bs_all
# Out:
#               All    연도
# 20년 총 업소수  160843  2020
# 21년 총 업소수  136517  2021
# 22년 총 업소수  147799  2022

# %%
table_us_all
# Out:
#              All    연도
# 20년 총 업소수  60644  2020
# 21년 총 업소수  45028  2021
# 22년 총 업소수  46270  2022

# %%
table_kn_all.drop('연도',axis=1,inplace=True)
table_kb_all.drop('연도',axis=1,inplace=True)
table_bs_all.drop('연도',axis=1,inplace=True)
table_us_all.drop('연도',axis=1,inplace=True)

# %%
table_20_22 = pd.concat([table_kn_all,table_kb_all,table_bs_all,table_us_all],axis=0)
table_20_22['시도명'] = ['경남','경남','경남','경북','경북','경북','부산','부산','부산','울산','울산','울산']
table_20_22['연도'] = [2020,2021,2022,2020,2021,2022,2020,2021,2022,2020,2021,2022]
table_20_22
# Out:
#               All 시도명    연도
# 20년 총 업소수  180137  경남  2020
# 21년 총 업소수  160448  경남  2021
# 22년 총 업소수  155793  경남  2022
# 20년 총 업소수  156549  경북  2020
# 21년 총 업소수  139311  경북  2021
# 22년 총 업소수  133941  경북  2022
# 20년 총 업소수  160843  부산  2020
# 21년 총 업소수  136517  부산  2021
# 22년 총 업소수  147799  부산  2022
# 20년 총 업소수   60644  울산  2020
# 21년 총 업소수   45028  울산  2021
# 22년 총 업소수   46270  울산  2022

# %%
plt.figure(figsize = (13, 8)) # 사이즈 설정
sns.barplot(data = table_20_22, x = '시도명', y = 'All', hue='연도' )
plt.ylim((40000, 200000))
plt.legend(loc = 'lower left', fontsize = 10)
plt.title("2020-2022년도 경남,경북,부산,울산 매장수 변화", fontsize = 16)
plt.show()

# %%
table_all_1 = pd.concat([table_kn_all,table_kb_all,table_bs_all,table_us_all],axis=0)
table_all_1 = pd.DataFrame(table_all_1)
table_all_1['연도'] = [2019,2020,2021,2022,2019,2020,2021,2022,2019,2020,2021,2022,2019,2020,2021,2022]
table_all_1['시도명'] = ['경남','경남','경남','경남','경북','경북','경북','경북','부산','부산','부산','부산','울산','울산','울산','울산']
table_all_1
# Out:
#               All    연도 시도명
# 19년 총 업소수  176289  2019  경남
# 20년 총 업소수  180137  2020  경남
# 21년 총 업소수  160448  2021  경남
# 22년 총 업소수  155793  2022  경남
# 19년 총 업소수  176289  2019  경북
# 20년 총 업소수  156549  2020  경북
# 21년 총 업소수  139311  2021  경북
# 22년 총 업소수  133941  2022  경북
# 19년 총 업소수  157516  2019  부산
# 20년 총 업소수  160843  2020  부산
# 21년 총 업소수  136517  2021  부산
# 22년 총 업소수  147799  2022  부산
# 19년 총 업소수   59371  2019  울산
# 20년 총 업소수   60644  2020  울산
# 21년 총 업소수   45028  2021  울산
# 22년 총 업소수   46270  2022  울산

# %%
plt.figure(figsize = (13, 8)) # 사이즈 설정
sns.barplot(data = table_all_1, x = '시도명', y = 'All',hue='연도' )
plt.ylim((40000, 200000))
plt.legend(loc = 'lower left', fontsize = 10)
plt.title("2019-2022년도 경남,경북,부산,울산 매장수 변화", fontsize = 16)
plt.show()

# %%
table_kn_all = pd.DataFrame(table_kn_all)
table_kn_all['연도'] = ['2019','2020','2021','2022']
table_kn_all
# Out:
#               All    연도
# 19년 총 업소수  176289  2019
# 20년 총 업소수  180137  2020
# 21년 총 업소수  160448  2021
# 22년 총 업소수  155793  2022

# %%
plt.figure(figsize = (4,4)) # 사이즈 설정
plt.title("2019-2022년도 경상남도 매장수 변화", fontsize = 12)
plt.ylim((105000, 200000))
sns.barplot(data = table_kn_all, x = '연도', y = 'All',color='orange' )
plt.show()

# %%
table_kb_all = pd.DataFrame(table_kb_all)
table_kb_all['연도'] = ['2019','2020','2021','2022']
table_kb_all

table_bs_all = pd.DataFrame(table_bs_all)
table_bs_all['연도'] = ['2019','2020','2021','2022']
table_bs_all

table_us_all = pd.DataFrame(table_us_all)
table_us_all['연도'] = ['2019','2020','2021','2022']
table_us_all
# Out:
#              All    연도
# 19년 총 업소수  59371  2019
# 20년 총 업소수  60644  2020
# 21년 총 업소수  45028  2021
# 22년 총 업소수  46270  2022

# %%
plt.figure(figsize = (4,4)) # 사이즈 설정
plt.title("2019-2022년도 경상북도 매장수 변화", fontsize = 12)
plt.ylim((105000, 200000))
sns.barplot(data = table_kb_all, x = '연도', y = 'All',color= 'pink' )
plt.show()

# %%
plt.figure(figsize = (4,4)) # 사이즈 설정
plt.title("2019-2022년도 부산광역시 매장수 변화", fontsize = 12)
plt.ylim((105000, 200000))
sns.barplot(data = table_bs_all, x = '연도', y = 'All',color= 'yellow' )
plt.show()

# %%
plt.figure(figsize = (4,4)) # 사이즈 설정
plt.title("2019-2022년도 울산광역시 매장수 변화", fontsize = 12)
plt.ylim((105000, 200000))
sns.barplot(data = table_kb_all, x = '연도', y = 'All',color= 'green' )
plt.show()

# %% [markdown]
# ## 지역별 & 업종별 매장 수 변화
#
# - 20~22 업종별 변화수
#   - 경남: table_kn_new
#   - 경북: table_kb_new
#   - 부산: table_bs_new
#   - 울산: table_us_new

# %%
table_kn_new
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수
# 상권업종대분류명
# 관광/여가/오락       4891       3184       3216
# 부동산            4604       4155       4782
# 생활서비스         27817      24706      25304
# 소매            55811      47757      47130
# 숙박             4256       3803       3944
# 스포츠              92        587       1793
# 음식            69170      65346      59020
# 학문/교육         13496      10910      10604
# All          180137     160448     155793

# %% [markdown]
# # 코로나단순지수 히트맵

# %%
jisu = pd.read_csv("/content/drive/MyDrive/8th_EDA/엄소은/전국_코로수단순피해지수.csv")

# %%
jisu = jisu.drop(['Unnamed: 9','Unnamed: 10'],axis=1)

# %%
jisu
# Out:
#    지역, 업종별 코로나피해지수   관광/여가/오락        부동산      생활서비스         소매         숙박  \
# 0               서울   7.402092  -2.979787  -1.089247   5.079925  14.811585
# 1               경기   1.609608 -12.523212  -8.564187  -1.623395  -3.656069
# 2               대전   4.709400  -7.198000  -2.206400   0.789900  10.512100
# 3               세종 -25.615984  -2.587287  -2.574564   0.286016   4.908453
# 4               충북  -1.497825  -7.947052  -2.821334   1.766966  -5.329963
# 5               충남  -1.066990  -4.197445  -1.223780   2.056345  -0.401664
# 6               경남   9.766734  -7.637460   1.660817   5.248282   0.597820
# 7               경북   5.987992 -11.147568   2.671024   6.557273  -0.160352
# 8               부산   2.916717 -19.115944  -0.598128  -3.513851   7.347713
# 9               울산   3.936756 -11.295076   0.672909   6.153251   6.217724
# 10              인천   1.117904  -9.995105  -2.344660   2.968067  -0.503560
# 11              강원   8.008084  -4.410633   0.723946   5.589159  -5.191440
# ...

# %%
jisu_nosport = jisu.drop(['스포츠'],axis=1)

# %%
jisu_nosport.columns = ['Region','tour/leisure','real estate','service','retail','housing','food','education']
jisu_nosport['Region'] = ['Seoul','Kyungki','Daejun','Sejong','Chungbuk','Chungnam','Kyungnam','Kyungbuk','Busan','Ulsan','Incheon','Kangwon','Jeju']

# %%
jisu_nosport = jisu_nosport.set_index('Region')

# %%
jisu_nosport
# Out:
#           tour/leisure  real estate    service     retail    housing  \
# Region
# Seoul         7.402092    -2.979787  -1.089247   5.079925  14.811585
# Kyungki       1.609608   -12.523212  -8.564187  -1.623395  -3.656069
# Daejun        4.709400    -7.198000  -2.206400   0.789900  10.512100
# Sejong      -25.615984    -2.587287  -2.574564   0.286016   4.908453
# Chungbuk     -1.497825    -7.947052  -2.821334   1.766966  -5.329963
# Chungnam     -1.066990    -4.197445  -1.223780   2.056345  -0.401664
# Kyungnam      9.766734    -7.637460   1.660817   5.248282   0.597820
# Kyungbuk      5.987992   -11.147568   2.671024   6.557273  -0.160352
# Busan         2.916717   -19.115944  -0.598128  -3.513851   7.347713
# Ulsan         3.936756   -11.295076   0.672909   6.153251   6.217724
# Incheon       1.117904    -9.995105  -2.344660   2.968067  -0.503560
# Kangwon       8.008084    -4.410633   0.723946   5.589159  -5.191440
# ...

# %%
# 히트맵 그리기
sns.set(rc = {'figure.figsize':(15,8)})
plt.title("Covid-19 Damage Rate")
sns.heatmap(jisu_nosport,linewidths=0.5,cmap="RdBu_r")
plt.show()
