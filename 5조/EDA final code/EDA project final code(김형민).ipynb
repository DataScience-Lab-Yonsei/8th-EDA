# %% [markdown]
# # EDA 5조 소상공인 상권 데이터를 활용한 소상공인 지원 정책 제언
# ## 소상공인 상권 데이터 분석
#
# ### 지역별 분류
# 1. 총 17개 지역으로 대분류된 소상공인 데이터를 팀원별로 분류하였음.
# 2. 코로나 팬데믹으로 인한 피해를 산출하고자 2022년 데이터 뿐만 아니라 2020년 데이터와 매출 데이터, 인구 수 데이터를 활용.

# %% [markdown]
# # 김형민(제주도, 강원도, 인천광역시)

# %% [markdown]
# ## 전처리
# 1. 각 지역별 2020 ~ 2022년 데이터 수집 및 분석.
# 2. 중복된 의미의 열 제거 및 null 값 대체.
# 3. 분석에 사용한 열의 경우, null 값이 존재하지 않았으며, 타 열에 관해서 null 값 대체 진행.

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
Gangwon20 = pd.read_csv("/content/drive/MyDrive/8th_EDA/김형민/상가업소정보_강원_202003.csv",encoding = 'cp949')
Incheon20 = pd.read_csv("/content/drive/MyDrive/8th_EDA/김형민/상가업소정보_인천_202003.csv",encoding = 'cp949')
Jeju20 = pd.read_csv("/content/drive/MyDrive/8th_EDA/김형민/상가업소정보_제주_202003.csv", encoding = 'cp949')

Gangwon21 = pd.read_csv("/content/drive/MyDrive/8th_EDA/김형민/소상공인시장진흥공단_상가(상권)정보_강원_202106.csv")
Incheon21 = pd.read_csv("/content/drive/MyDrive/8th_EDA/김형민/소상공인시장진흥공단_상가(상권)정보_인천_202106.csv")
Jeju21 = pd.read_csv("/content/drive/MyDrive/8th_EDA/김형민/소상공인시장진흥공단_상가(상권)정보_제주_202106.csv")

Gangwon22 = pd.read_csv("/content/drive/MyDrive/8th_EDA/김형민/소상공인시장진흥공단_상가(상권)정보_강원_202203.csv")
Incheon22 = pd.read_csv("/content/drive/MyDrive/8th_EDA/김형민/소상공인시장진흥공단_상가(상권)정보_인천_202203.csv")
Jeju22 = pd.read_csv("/content/drive/MyDrive/8th_EDA/김형민/소상공인시장진흥공단_상가(상권)정보_제주_202203.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Gangwon20.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
Gangwon21.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
Gangwon22.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
Incheon20.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
Incheon21.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
Incheon22.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
Jeju20.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
Jeju21.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)
Jeju22.drop(labels=['상권업종대분류코드' ,'상권업종중분류코드','상권업종소분류코드','표준산업분류코드','시도코드','시도명','시군구코드','행정동코드','법정동코드','지번코드','대지구분코드','대지구분명','지번본번지','지번부번지','도로명코드','건물본번지','건물부번지','건물관리번호','건물명','도로명주소','구우편번호','신우편번호','호정보'], axis=1, inplace=True)

# %%
Gangwon20["지점명"] = Gangwon20["지점명"].fillna("0")
Gangwon20["표준산업분류명"] = Gangwon20["표준산업분류명"].fillna("0")
Gangwon20["동정보"] = Gangwon20["동정보"].fillna("0")
Gangwon20["층정보"] = Gangwon20["층정보"].fillna("0")

Gangwon21["지점명"] = Gangwon21["지점명"].fillna("0")
Gangwon21["표준산업분류명"] = Gangwon21["표준산업분류명"].fillna("0")
Gangwon21["동정보"] = Gangwon21["동정보"].fillna("0")
Gangwon21["층정보"] = Gangwon21["층정보"].fillna("0")

Gangwon22["지점명"] = Gangwon22["지점명"].fillna("0")
Gangwon22["표준산업분류명"] = Gangwon22["표준산업분류명"].fillna("0")
Gangwon22["동정보"] = Gangwon22["동정보"].fillna("0")
Gangwon22["층정보"] = Gangwon22["층정보"].fillna("0")

Incheon20["지점명"] = Incheon20["지점명"].fillna("0")
Incheon20["표준산업분류명"] = Incheon20["표준산업분류명"].fillna("0")
Incheon20["동정보"] = Incheon20["동정보"].fillna("0")
Incheon20["층정보"] = Incheon20["층정보"].fillna("0")

Incheon21["지점명"] = Incheon21["지점명"].fillna("0")
Incheon21["표준산업분류명"] = Incheon21["표준산업분류명"].fillna("0")
Incheon21["동정보"] = Incheon21["동정보"].fillna("0")
Incheon21["층정보"] = Incheon21["층정보"].fillna("0")

Incheon22["지점명"] = Incheon22["지점명"].fillna("0")
Incheon22["표준산업분류명"] = Incheon22["표준산업분류명"].fillna("0")
Incheon22["동정보"] = Incheon22["동정보"].fillna("0")
Incheon22["층정보"] = Incheon22["층정보"].fillna("0")

Jeju20["지점명"] = Jeju20["지점명"].fillna("0")
Jeju20["표준산업분류명"] = Jeju20["표준산업분류명"].fillna("0")
Jeju20["동정보"] = Jeju20["동정보"].fillna("0")
Jeju20["층정보"] = Jeju20["층정보"].fillna("0")

Jeju21["지점명"] = Jeju21["지점명"].fillna("0")
Jeju21["표준산업분류명"] = Jeju21["표준산업분류명"].fillna("0")
Jeju21["동정보"] = Jeju21["동정보"].fillna("0")
Jeju21["층정보"] = Jeju21["층정보"].fillna("0")

Jeju22["지점명"] = Jeju22["지점명"].fillna("0")
Jeju22["표준산업분류명"] = Jeju22["표준산업분류명"].fillna("0")
Jeju22["동정보"] = Jeju22["동정보"].fillna("0")
Jeju22["층정보"] = Jeju22["층정보"].fillna("0")

# %% [markdown]
# ## 지역별 EDA

# %% [markdown]
# ### 강릉

# %%
table0 = pd.pivot_table(data = Gangwon20, index = "상권업종대분류명", values='상가업소번호', aggfunc = "count", margins=True)
table0.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       118173
# 음식         46140
# 소매         38520
# 생활서비스      16628
# 학문/교육       6821
# 숙박          5025
# 관광/여가/오락    2749
# 부동산         2233
# 스포츠           57

# %%
table1 = pd.pivot_table(data = Gangwon21, index = "상권업종대분류명", values='상가업소번호', aggfunc = "count", margins=True)
table1.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       106868
# 음식         43680
# 소매         33254
# 생활서비스      15211
# 학문/교육       5277
# 숙박          5099
# 관광/여가/오락    1997
# 부동산         1989
# 스포츠          361

# %%
table2 = pd.pivot_table(data = Gangwon22, index = "상권업종대분류명", values='상가업소번호', aggfunc = "count", margins=True)
table2.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       103371
# 음식         39135
# 소매         32597
# 생활서비스      15633
# 숙박          5453
# 학문/교육       5211
# 부동산         2211
# 관광/여가/오락    2006
# 스포츠         1125

# %%
table3 = pd.concat([table0, table1, table2], axis = 1)
table3.columns = ['20년 총 업소수', '21년 총 업소수', '22년 총 업소수']
table3
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수
# 상권업종대분류명
# 관광/여가/오락       2749       1997       2006
# 부동산            2233       1989       2211
# 생활서비스         16628      15211      15633
# 소매            38520      33254      32597
# 숙박             5025       5099       5453
# 스포츠              57        361       1125
# 음식            46140      43680      39135
# 학문/교육          6821       5277       5211
# All          118173     106868     103371

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (7,739 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
from matplotlib import rcParams
import matplotlib.pyplot as plt
import seaborn as sns

# figure size in inches
plt.subplot(131)
rcParams['figure.figsize'] = 15,30
sns.countplot(x="시군구명", data= Gangwon20)
plt.title("20년도 강원도 시군구별 소상공인 상권 수")

plt.subplot(132)
sns.countplot(x="시군구명", data= Gangwon21)
plt.title("21년도 강원도 시군구별 소상공인 상권 수")

plt.subplot(133)
sns.countplot(x="시군구명", data= Gangwon22)
plt.title("22년도 강원도 시군구별 소상공인 상권 수")
plt.show()

# %% [markdown]
# #### 소결론
# 1. 절대적인 업소 수만을 비교해보았을 때, 인구가 비교적 많은 강릉시, 속초시 뿐만 아니라 대부분의 강원도 시군구의 경우 21년에 비해 22년에 업소 수가 많이 줄어들었음을 확인.
# 2. 20년에서 21년으로 넘어갈 때, 절대적 업소 수가 많이 모여있는 강릉시, 원주시, 속초시, 춘천시의 경우 유의미한 업소 감소폭이 존재했음.
# 3. 전체적으로 절대적인 업소 수가 줄었다는 소결론을 도출할 수 있음. 정확한 분석을 위해 인구 수와 매출 데이터와의 연계성이 필요.

# %%
#Gangwonsmall = Gangwon[Gangwon['시군구명'] == ['강릉시','원주시','춘천시','속초시']]
gr20 = Gangwon20[Gangwon20['시군구명'] == '강릉시']
gr21 = Gangwon21[Gangwon21['시군구명'] == '강릉시']
gr22 = Gangwon22[Gangwon22['시군구명'] == '강릉시']
wj20 = Gangwon20[Gangwon20['시군구명'] == '원주시']
wj21 = Gangwon21[Gangwon21['시군구명'] == '원주시']
wj22 = Gangwon22[Gangwon22['시군구명'] == '원주시']
ch20 = Gangwon20[Gangwon20['시군구명'] == '춘천시']
ch21 = Gangwon21[Gangwon21['시군구명'] == '춘천시']
ch22 = Gangwon22[Gangwon22['시군구명'] == '춘천시']
sc20 = Gangwon20[Gangwon20['시군구명'] == '속초시']
sc21 = Gangwon21[Gangwon21['시군구명'] == '속초시']
sc22 = Gangwon22[Gangwon22['시군구명'] == '속초시']

# %%
gr20_pivot = pd.pivot_table(data=gr20, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
gr21_pivot = pd.pivot_table(data=gr21, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
gr22_pivot = pd.pivot_table(data=gr22, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
gr_table = pd.concat([gr20_pivot, gr21_pivot, gr22_pivot], axis = 1)
gr_table.columns = ['20년', '21년', '22년']
gr_table
# Out:
#             20년    21년    22년
# 상권업종대분류명
# 관광/여가/오락    489    347    321
# 부동산         249    270    336
# 생활서비스      2578   2514   2551
# 소매         5217   4936   4931
# 숙박          709    691    781
# 스포츠           8     53    164
# 음식         6726   7180   6435
# 학문/교육      1210   1078   1008
# 합계        17186  17069  16527

# %%
rcParams['figure.figsize'] = 20,8.27
plt.subplot(131)
sns.countplot(x="상권업종대분류명", data= gr20)
plt.title("20년 강릉시 업종별 소상공인 상권 수")

plt.subplot(132)
sns.countplot(x="상권업종대분류명", data= gr21)
plt.title("21년 강릉시 업종별 소상공인 상권 수")

plt.subplot(133)
sns.countplot(x="상권업종대분류명", data= gr22)
plt.title("22년 강릉시 업종별 소상공인 상권 수")

plt.show()

# %%
wj20_pivot = pd.pivot_table(data=wj20, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
wj21_pivot = pd.pivot_table(data=wj21, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
wj22_pivot = pd.pivot_table(data=wj22, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
wj_table = pd.concat([wj20_pivot, wj21_pivot, wj22_pivot], axis = 1)
wj_table.columns = ['20년', '21년', '22년']
wj_table
# Out:
#             20년    21년    22년
# 상권업종대분류명
# 관광/여가/오락    789    423    449
# 부동산         770    556    646
# 생활서비스      4131   3405   3721
# 소매         8540   6366   6877
# 숙박          385    350    359
# 스포츠          21     74    195
# 음식         9924   7393   7288
# 학문/교육      2059   1250   1378
# 합계        26619  19817  20913

# %%
rcParams['figure.figsize'] = 20,8.27
plt.subplot(131)
sns.countplot(x="상권업종대분류명", data= wj20)
plt.title("20년 원주시 업종별 소상공인 상권 수")

plt.subplot(132)
sns.countplot(x="상권업종대분류명", data= wj21)
plt.title("21년 원주시 업종별 소상공인 상권 수")

plt.subplot(133)
sns.countplot(x="상권업종대분류명", data= wj22)
plt.title("22년 원주시 업종별 소상공인 상권 수")

plt.show()

# %%
ch20_pivot = pd.pivot_table(data=ch20, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
ch21_pivot = pd.pivot_table(data=ch21, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
ch22_pivot = pd.pivot_table(data=ch22, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
ch_table = pd.concat([ch20_pivot, ch21_pivot, ch22_pivot], axis = 1)
ch_table.columns = ['20년', '21년', '22년']
ch_table
# Out:
#             20년    21년    22년
# 상권업종대분류명
# 관광/여가/오락    566    352    379
# 부동산         554    433    453
# 생활서비스      3031   2525   2774
# 소매         5367   4279   4503
# 숙박          407    380    404
# 스포츠          15     95    226
# 음식         7204   5810   5623
# 학문/교육      1488    984   1059
# 합계        18632  14858  15421

# %%
rcParams['figure.figsize'] = 20,8.27
plt.subplot(131)
sns.countplot(x="상권업종대분류명", data= ch20)
plt.title("20년 춘천시 업종별 소상공인 상권 수")

plt.subplot(132)
sns.countplot(x="상권업종대분류명", data= ch21)
plt.title("21년 춘천시 업종별 소상공인 상권 수")

plt.subplot(133)
sns.countplot(x="상권업종대분류명", data= ch22)
plt.title("22년 춘천시 업종별 소상공인 상권 수")

plt.show()

# %%
sc20_pivot = pd.pivot_table(data=sc20, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
sc21_pivot = pd.pivot_table(data=sc21, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
sc22_pivot = pd.pivot_table(data=sc22, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
sc_table = pd.concat([sc20_pivot, sc21_pivot, sc22_pivot], axis = 1)
sc_table.columns = ['20년', '21년','22년']
sc_table
# Out:
#            20년   21년   22년
# 상권업종대분류명
# 관광/여가/오락   209   176   166
# 부동산         88   107   119
# 생활서비스     1012   995  1018
# 소매        2633  2636  2485
# 숙박         318   311   321
# 스포츠          4    28    55
# 음식        3408  3411  2900
# 학문/교육      393   336   325
# 합계        8065  8000  7389

# %% [markdown]
# #### 소결론
# 1. 절대적인 업수 수를 비교하기 위해서는 다른 독립변수들의 고정이 필요하다. 예를 들면, 업소 수의 감소가 인구의 변화 때문일 수도 있고 사회적으로 해당 업종이 유망하지 않아서 줄어들 가능성도 있음. 그렇기 때문에 추세를 비교하는 것이 필요하다고 판단.
# 2. 코로나 피해를 본 업종을 선정하기 위해서는,
#
#   1)20년 대비 21년 증감률이 음수여야 한다.
#
#   2)21년 대비 22년 증감률이 양수라면, 결국 감소했다가 증가했다는 의미인데, 이는 사회적으로 업소 수가 감소할 필요없는데 21년에 감소했다는 것을 의미. 이는 코로나의 영향력으로 나는 해석하기로 함. 21년 대비 22년 증감률이 음수라면, 이는 코로나로 인한 거리두기 등의 정책으로 인한 외부시차라고 판단. 이 또한, 코로나 피해라고 해석 가능.
# 3. 위의 기준으로 판단하였을 때, 강원도 특정 4개의 시의 경우,
#
#   1) 강릉: 관광/여가/오락, 생활서비스, 소매, 음식
#
#   2) 원주: 모든 업종
#
#   3) 춘천: 모든 업종
#
#   4) 속초: 관광/여가/오락, 생활서비스, 소매, 음식
#
# 4. 스포츠업의 경우, 20년 대비 폭발적인 업소 수 증가가 보였음. 사회 분위기 (헬스, 미용의 증가)의 특성에 따라 많이 증가했고 코로나에 의한 피해가 타 업종에 비해 컸다고 해석하기 힘듬.

# %% [markdown]
# ### 제주도

# %%
table00 = pd.pivot_table(data = Jeju20, index = "상권업종대분류명", values='상가업소번호', aggfunc = "count", margins=True)
table00.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All        45332
# 음식         18102
# 소매         13517
# 생활서비스       6046
# 숙박          2968
# 학문/교육       2916
# 관광/여가/오락     917
# 부동산          815
# 스포츠           51

# %%
table11 = pd.pivot_table(data = Jeju21, index = "상권업종대분류명", values='상가업소번호', aggfunc = "count", margins=True)
table11.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All        45584
# 음식         20178
# 소매         12369
# 생활서비스       5810
# 숙박          2859
# 학문/교육       2548
# 부동산          885
# 관광/여가/오락     765
# 스포츠          170

# %%
table22 = pd.pivot_table(data = Jeju22, index = "상권업종대분류명", values='상가업소번호', aggfunc = "count", margins=True)
table22.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All        48772
# 음식         20196
# 소매         13368
# 생활서비스       6516
# 숙박          3323
# 학문/교육       2717
# 부동산         1161
# 관광/여가/오락     905
# 스포츠          586

# %%
table33 = pd.concat([table00, table11, table22], axis = 1)
table33.columns = ['20년 총 업소수', '21년 총 업소수', '22년 총 업소수']
table33
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수
# 상권업종대분류명
# 관광/여가/오락        917        765        905
# 부동산             815        885       1161
# 생활서비스          6046       5810       6516
# 소매            13517      12369      13368
# 숙박             2968       2859       3323
# 스포츠              51        170        586
# 음식            18102      20178      20196
# 학문/교육          2916       2548       2717
# All           45332      45584      48772

# %%
sgp20 = Jeju20[Jeju20['시군구명'] == '서귀포시']
sgp21 = Jeju21[Jeju21['시군구명'] == '서귀포시']
sgp22 = Jeju22[Jeju22['시군구명'] == '서귀포시']
jj20 = Jeju20[Jeju20['시군구명'] == '제주시']
jj21 = Jeju21[Jeju21['시군구명'] == '제주시']
jj22 = Jeju22[Jeju22['시군구명'] == '제주시']

# %%
sgp20_pivot = pd.pivot_table(data=sgp20, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
sgp21_pivot = pd.pivot_table(data=sgp21, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
sgp22_pivot = pd.pivot_table(data=sgp22, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
sgp_table = pd.concat([sgp20_pivot, sgp21_pivot, sgp22_pivot], axis = 1)
sgp_table.columns = ['20년', '21년', '22년']
sgp_table
# Out:
#             20년    21년    22년
# 상권업종대분류명
# 관광/여가/오락    170    184    232
# 부동산         180    219    286
# 생활서비스      1283   1322   1508
# 소매         3279   3367   3730
# 숙박         1097   1105   1246
# 스포츠           6     29    161
# 음식         5403   6466   6464
# 학문/교육       483    481    574
# 합계        11901  13173  14201

# %%
rcParams['figure.figsize'] = 20,8.27
plt.subplot(131)
sns.countplot(x="상권업종대분류명", data= sgp20)
plt.title("20년 서귀포시 업종별 소상공인 상권 수")

plt.subplot(132)
sns.countplot(x="상권업종대분류명", data= sgp21)
plt.title("21년 서귀포시 업종별 소상공인 상권 수")

plt.subplot(133)
sns.countplot(x="상권업종대분류명", data= sgp22)
plt.title("22년 서귀포시 업종별 소상공인 상권 수")

plt.show()

# %%
jj20_pivot = pd.pivot_table(data=jj20, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
jj21_pivot = pd.pivot_table(data=jj21, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
jj22_pivot = pd.pivot_table(data=jj22, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
jj_table = pd.concat([jj20_pivot, jj21_pivot, jj22_pivot], axis = 1)
jj_table.columns = ['20년', '21년', '22년']
jj_table
# Out:
#             20년    21년    22년
# 상권업종대분류명
# 관광/여가/오락    747    581    673
# 부동산         635    666    875
# 생활서비스      4655   4488   5008
# 소매         9231   9002   9638
# 숙박         1871   1754   2077
# 스포츠          45    141    425
# 음식        12511  13712  13732
# 학문/교육      2433   2067   2143
# 합계        32128  32411  34571

# %%
rcParams['figure.figsize'] = 20,8.27
plt.subplot(131)
sns.countplot(x="상권업종대분류명", data= jj20)
plt.title("20년 제주시 업종별 소상공인 상권 수")

plt.subplot(132)
sns.countplot(x="상권업종대분류명", data= jj21)
plt.title("21년 제주시 업종별 소상공인 상권 수")

plt.subplot(133)
sns.countplot(x="상권업종대분류명", data= jj22)
plt.title("22년 제주시 업종별 소상공인 상권 수")

plt.show()

# %% [markdown]
# #### 소결론
# 제주시의 경우, 관광/여가/오락, 생활서비스, 소매, 숙박, 학문/교육 업종이 21년에 감소하였으나, 22년에 빠른 회복세를 보였음.
#
# 음식업의 경우, 코로나로 인해 큰 피해를 보았다고 보기에는 힘듬.

# %% [markdown]
# ### 인천광역시

# %%
table000 = pd.pivot_table(data = Incheon20, index = "상권업종대분류명", values='상가업소번호', aggfunc = "count", margins=True)
table000.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       139925
# 소매         47233
# 음식         45387
# 생활서비스      23759
# 학문/교육      11038
# 부동산         5413
# 관광/여가/오락    5207
# 숙박          1813
# 스포츠           75

# %%
table111 = pd.pivot_table(data = Incheon21, index = "상권업종대분류명", values='상가업소번호', aggfunc = "count", margins=True)
table111.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       102280
# 음식         36952
# 소매         30939
# 생활서비스      19006
# 학문/교육       6939
# 부동산         4039
# 관광/여가/오락    2502
# 숙박          1503
# 스포츠          400

# %%
table222 = pd.pivot_table(data = Incheon22, index = "상권업종대분류명", values='상가업소번호', aggfunc = "count", margins=True)
table222.sort_values(by='상가업소번호',ascending=False)
# Out:
#           상가업소번호
# 상권업종대분류명
# All       110782
# 음식         36016
# 소매         34343
# 생활서비스      21354
# 학문/교육       7923
# 부동산         5076
# 관광/여가/오락    3033
# 숙박          1630
# 스포츠         1407

# %%
table333 = pd.concat([table000, table111, table222], axis = 1)
table333.columns = ['20년 총 업소수', '21년 총 업소수', '22년 총 업소수']
table333
# Out:
#           20년 총 업소수  21년 총 업소수  22년 총 업소수
# 상권업종대분류명
# 관광/여가/오락       5207       2502       3033
# 부동산            5413       4039       5076
# 생활서비스         23759      19006      21354
# 소매            47233      30939      34343
# 숙박             1813       1503       1630
# 스포츠              75        400       1407
# 음식            45387      36952      36016
# 학문/교육         11038       6939       7923
# All          139925     102280     110782

# %% [markdown]
# #### 소결론
# 1. 인천의 경우, 21년 중구, 강화군을 제외한 모든 시군구에서 큰 업소 수 감소가 존재.
# 2. 남동구, 부평구, 미추홀구, 계양구의 경우 30% 이상 감소
# 3. 22년에는 21년에 비해 회복하는 추세를 보였음.

# %%
nd20 = Incheon20[Incheon20['시군구명'] == '남동구']
nd21 = Incheon21[Incheon21['시군구명'] == '남동구']
nd22 = Incheon22[Incheon22['시군구명'] == '남동구']

bp20 = Incheon20[Incheon20['시군구명'] == '부평구']
bp21 = Incheon21[Incheon21['시군구명'] == '부평구']
bp22 = Incheon22[Incheon22['시군구명'] == '부평구']

mch200 = Incheon20[Incheon20['시군구명'] == '미추홀구']
ng20 = Incheon20[Incheon20['시군구명'] == '남구']
mch20 = pd.concat([mch200,ng20], axis = 0)
mch21 = Incheon21[Incheon21['시군구명'] == '미추홀구']
mch22 = Incheon22[Incheon22['시군구명'] == '미추홀구']

gy20 = Incheon20[Incheon20['시군구명'] == '계양구']
gy21 = Incheon21[Incheon21['시군구명'] == '계양구']
gy22 = Incheon22[Incheon22['시군구명'] == '계양구']

# %%
nd20_pivot = pd.pivot_table(data=nd20, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
nd21_pivot = pd.pivot_table(data=nd21, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
nd22_pivot = pd.pivot_table(data=nd22, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
nd_table = pd.concat([nd20_pivot, nd21_pivot, nd22_pivot], axis = 1)
nd_table.columns = ['20년', '21년', '22년']
nd_table
# Out:
#             20년    21년    22년
# 상권업종대분류명
# 관광/여가/오락   1160    466    606
# 부동산        1125    761    904
# 생활서비스      4768   3432   3918
# 소매         8938   5773   6413
# 숙박          127     63     69
# 스포츠          15     76    274
# 음식         9044   5956   6107
# 학문/교육      2413   1395   1538
# 합계        27590  17922  19829

# %%
rcParams['figure.figsize'] = 20,8.27
plt.subplot(131)
sns.countplot(x="상권업종대분류명", data= nd20)
plt.title("20년 남동구 업종별 소상공인 상권 수")

plt.subplot(132)
sns.countplot(x="상권업종대분류명", data= nd21)
plt.title("21년 남동구 업종별 소상공인 상권 수")

plt.subplot(133)
sns.countplot(x="상권업종대분류명", data= nd22)
plt.title("22년 남동구 업종별 소상공인 상권 수")

plt.show()

# %%
bp20_pivot = pd.pivot_table(data=bp20, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
bp21_pivot = pd.pivot_table(data=bp21, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
bp22_pivot = pd.pivot_table(data=bp22, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
bp_table = pd.concat([bp20_pivot, bp21_pivot, bp22_pivot], axis = 1)
bp_table.columns = ['20년', '21년', '22년']
bp_table
# Out:
#             20년    21년    22년
# 상권업종대분류명
# 관광/여가/오락    956    434    500
# 부동산         971    677    764
# 생활서비스      4772   3730   3880
# 소매         8212   5361   5567
# 숙박          236    117    130
# 스포츠          11     62    187
# 음식         7369   5392   5317
# 학문/교육      2099   1188   1319
# 합계        24626  16961  17664

# %%
rcParams['figure.figsize'] = 20,8.27
plt.subplot(131)
sns.countplot(x="상권업종대분류명", data= bp20)
plt.title("20년 부평구 업종별 소상공인 상권 수")

plt.subplot(132)
sns.countplot(x="상권업종대분류명", data= bp21)
plt.title("21년 부평구 업종별 소상공인 상권 수")

plt.subplot(133)
sns.countplot(x="상권업종대분류명", data= bp22)
plt.title("22년 부평구 업종별 소상공인 상권 수")

plt.show()

# %%
mch20_pivot = pd.pivot_table(data=mch20, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
mch21_pivot = pd.pivot_table(data=mch21, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
mch22_pivot = pd.pivot_table(data=mch22, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
mch_table = pd.concat([mch20_pivot, mch21_pivot, mch22_pivot], axis = 1)
mch_table.columns = ['20년', '21년', '22년']
mch_table
# Out:
#             20년    21년    22년
# 상권업종대분류명
# 관광/여가/오락   1006    380    465
# 부동산         941    624    768
# 생활서비스      4139   3165   3424
# 소매         7757   4543   5101
# 숙박          242    168    139
# 스포츠          11     52    159
# 음식         6936   4782   4329
# 학문/교육      1522    891    974
# 합계        22554  14605  15359

# %%
rcParams['figure.figsize'] = 20,8.27
plt.subplot(131)
sns.countplot(x="상권업종대분류명", data= mch20)
plt.title("20년 미추홀구 업종별 소상공인 상권 수")

plt.subplot(132)
sns.countplot(x="상권업종대분류명", data= mch21)
plt.title("21년 미추홀구 업종별 소상공인 상권 수")

plt.subplot(133)
sns.countplot(x="상권업종대분류명", data= mch22)
plt.title("22년 미추홀구 업종별 소상공인 상권 수")

plt.show()

# %%
gy20_pivot = pd.pivot_table(data=gy20, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
gy21_pivot = pd.pivot_table(data=gy21, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
gy22_pivot = pd.pivot_table(data=gy22, index = '상권업종대분류명', values="상가업소번호", aggfunc=['count'],
                     fill_value = 0, margins = True, margins_name = "합계")
gy_table = pd.concat([gy20_pivot, gy21_pivot, gy22_pivot], axis = 1)
gy_table.columns = ['20년', '21년', '22년']
gy_table
# Out:
#             20년   21년    22년
# 상권업종대분류명
# 관광/여가/오락    655   284    327
# 부동산         516   347    397
# 생활서비스      2393  1821   2096
# 소매         4233  2815   3154
# 숙박           79    60     61
# 스포츠          16    55    140
# 음식         4146  3038   3118
# 학문/교육      1317   726    823
# 합계        13355  9146  10116

# %%
rcParams['figure.figsize'] = 20,8.27
plt.subplot(131)
sns.countplot(x="상권업종대분류명", data= gy20)
plt.title("20년 계양구 업종별 소상공인 상권 수")

plt.subplot(132)
sns.countplot(x="상권업종대분류명", data= gy21)
plt.title("21년 계양구 업종별 소상공인 상권 수")

plt.subplot(133)
sns.countplot(x="상권업종대분류명", data= gy22)
plt.title("22년 계양구 업종별 소상공인 상권 수")

plt.show()

# %% [markdown]
# #### 소결론
# 1. 전체적으로 모든 업종에서 21년에 큰 피해가 인천에 존재.
# 2. 특히나, 인천의 경우, 관광/여가/오락 업종이 매우 큰 폭으로 업소 수가 감소
# 3. 관광/여가/오락 > 숙박 > 학문 > 소매 순으로 매우 큰 폭으로 업소 수 감소

# %% [markdown]
# ### 인구 수 데이터를 활용한 지역별 EDA

# %%
gr20_pop = gr20_pivot
gr20_pop['20년 인구 수'] = 215603
gr20_pop.columns = ['업소 수','20년 인구 수']
gr20_pop['매장 커버리지'] = round(gr20_pop['20년 인구 수'] / gr20_pop['업소 수'], 2)
gr20_pop
# Out:
#            업소 수  20년 인구 수   매장 커버리지
# 상권업종대분류명
# 관광/여가/오락    489    215603    440.91
# 부동산         249    215603    865.88
# 생활서비스      2578    215603     83.63
# 소매         5217    215603     41.33
# 숙박          709    215603    304.09
# 스포츠           8    215603  26950.38
# 음식         6726    215603     32.06
# 학문/교육      1210    215603    178.18
# 합계        17186    215603     12.55

# %%
gr21_pop = gr21_pivot
gr21_pop['21년 인구 수'] = 215322
gr21_pop.columns = ['업소 수','21년 인구 수']
gr21_pop['매장 커버리지'] = round(gr21_pop['21년 인구 수'] / gr21_pop['업소 수'], 2)
gr21_pop
# Out:
#            업소 수  21년 인구 수  매장 커버리지
# 상권업종대분류명
# 관광/여가/오락    347    215322   620.52
# 부동산         270    215322   797.49
# 생활서비스      2514    215322    85.65
# 소매         4936    215322    43.62
# 숙박          691    215322   311.61
# 스포츠          53    215322  4062.68
# 음식         7180    215322    29.99
# 학문/교육      1078    215322   199.74
# 합계        17069    215322    12.61

# %%
gr22_pop = gr22_pivot
gr22_pop['22년 인구 수'] = 214307
gr22_pop.columns = ['업소 수','22년 인구 수']
gr22_pop['매장 커버리지'] = round(gr22_pop['22년 인구 수'] / gr22_pop['업소 수'], 2)
gr22_pop
# Out:
#            업소 수  22년 인구 수  매장 커버리지
# 상권업종대분류명
# 관광/여가/오락    321    214307   667.62
# 부동산         336    214307   637.82
# 생활서비스      2551    214307    84.01
# 소매         4931    214307    43.46
# 숙박          781    214307   274.40
# 스포츠         164    214307  1306.75
# 음식         6435    214307    33.30
# 학문/교육      1008    214307   212.61
# 합계        16527    214307    12.97

# %%
wj20_pop = wj20_pivot
wj20_pop['20년 인구 수'] = 357710
wj20_pop.columns = ['업소 수','20년 인구 수']
wj20_pop['매장 커버리지'] = round(wj20_pop['20년 인구 수'] / wj20_pop['업소 수'], 2)
wj20_pop
# Out:
#            업소 수  20년 인구 수   매장 커버리지
# 상권업종대분류명
# 관광/여가/오락    789    357710    453.37
# 부동산         770    357710    464.56
# 생활서비스      4131    357710     86.59
# 소매         8540    357710     41.89
# 숙박          385    357710    929.12
# 스포츠          21    357710  17033.81
# 음식         9924    357710     36.04
# 학문/교육      2059    357710    173.73
# 합계        26619    357710     13.44

# %%
wj21_pop = wj21_pivot
wj21_pop['21년 인구 수'] = 361056
wj21_pop.columns = ['업소 수','21년 인구 수']
wj21_pop['매장 커버리지'] = round(wj21_pop['21년 인구 수'] / wj21_pop['업소 수'], 2)
wj21_pop
# Out:
#            업소 수  21년 인구 수  매장 커버리지
# 상권업종대분류명
# 관광/여가/오락    423    361056   853.56
# 부동산         556    361056   649.38
# 생활서비스      3405    361056   106.04
# 소매         6366    361056    56.72
# 숙박          350    361056  1031.59
# 스포츠          74    361056  4879.14
# 음식         7393    361056    48.84
# 학문/교육      1250    361056   288.84
# 합계        19817    361056    18.22

# %%
wj22_pop = wj22_pivot
wj22_pop['22년 인구 수'] = 335827
wj22_pop.columns = ['업소 수','22년 인구 수']
wj22_pop['매장 커버리지'] = round(wj22_pop['22년 인구 수'] / wj22_pop['업소 수'], 2)
wj22_pop
# Out:
#            업소 수  22년 인구 수  매장 커버리지
# 상권업종대분류명
# 관광/여가/오락    449    335827   747.94
# 부동산         646    335827   519.86
# 생활서비스      3721    335827    90.25
# 소매         6877    335827    48.83
# 숙박          359    335827   935.45
# 스포츠         195    335827  1722.19
# 음식         7288    335827    46.08
# 학문/교육      1378    335827   243.71
# 합계        20913    335827    16.06

# %%
ch20_pop = ch20_pivot
ch20_pop['20년 인구 수'] = 286489
ch20_pop.columns = ['업소 수','20년 인구 수']
ch20_pop['매장 커버리지'] = round(ch20_pop['20년 인구 수'] / ch20_pop['업소 수'], 2)
ch20_pop
# Out:
#            업소 수  20년 인구 수   매장 커버리지
# 상권업종대분류명
# 관광/여가/오락    566    286489    506.16
# 부동산         554    286489    517.13
# 생활서비스      3031    286489     94.52
# 소매         5367    286489     53.38
# 숙박          407    286489    703.90
# 스포츠          15    286489  19099.27
# 음식         7204    286489     39.77
# 학문/교육      1488    286489    192.53
# 합계        18632    286489     15.38

# %%
ch21_pop = ch21_pivot
ch21_pop['21년 인구 수'] = 288320
ch21_pop.columns = ['업소 수','21년 인구 수']
ch21_pop['매장 커버리지'] = round(ch21_pop['21년 인구 수'] / ch21_pop['업소 수'], 2)
ch21_pop
# Out:
#            업소 수  21년 인구 수  매장 커버리지
# 상권업종대분류명
# 관광/여가/오락    352    288320   819.09
# 부동산         433    288320   665.87
# 생활서비스      2525    288320   114.19
# 소매         4279    288320    67.38
# 숙박          380    288320   758.74
# 스포츠          95    288320  3034.95
# 음식         5810    288320    49.62
# 학문/교육       984    288320   293.01
# 합계        14858    288320    19.41

# %%
ch22_pop = ch22_pivot
ch22_pop['22년 인구 수'] = 278915
ch22_pop.columns = ['업소 수','22년 인구 수']
ch22_pop['매장 커버리지'] = round(ch22_pop['22년 인구 수'] / ch22_pop['업소 수'], 2)
ch22_pop
# Out:
#            업소 수  22년 인구 수  매장 커버리지
# 상권업종대분류명
# 관광/여가/오락    379    278915   735.92
# 부동산         453    278915   615.71
# 생활서비스      2774    278915   100.55
# 소매         4503    278915    61.94
# 숙박          404    278915   690.38
# 스포츠         226    278915  1234.14
# 음식         5623    278915    49.60
# 학문/교육      1059    278915   263.38
# 합계        15421    278915    18.09

# %%
sc20_pop = sc20_pivot
sc20_pop['20년 인구 수'] = 83674
sc20_pop.columns = ['업소 수','20년 인구 수']
sc20_pop['매장 커버리지'] = round(sc20_pop['20년 인구 수'] / sc20_pop['업소 수'], 2)
sc20_pop
# Out:
#           업소 수  20년 인구 수   매장 커버리지
# 상권업종대분류명
# 관광/여가/오락   209     83674    400.35
# 부동산         88     83674    950.84
# 생활서비스     1012     83674     82.68
# 소매        2633     83674     31.78
# 숙박         318     83674    263.13
# 스포츠          4     83674  20918.50
# 음식        3408     83674     24.55
# 학문/교육      393     83674    212.91
# 합계        8065     83674     10.37

# %%
sc21_pop = sc21_pivot
sc21_pop['21년 인구 수'] = 83825
sc21_pop.columns = ['업소 수','21년 인구 수']
sc21_pop['매장 커버리지'] = round(sc21_pop['21년 인구 수'] / sc21_pop['업소 수'], 2)
sc21_pop
# Out:
#           업소 수  21년 인구 수  매장 커버리지
# 상권업종대분류명
# 관광/여가/오락   176     83825   476.28
# 부동산        107     83825   783.41
# 생활서비스      995     83825    84.25
# 소매        2636     83825    31.80
# 숙박         311     83825   269.53
# 스포츠         28     83825  2993.75
# 음식        3411     83825    24.57
# 학문/교육      336     83825   249.48
# 합계        8000     83825    10.48

# %%
sc22_pop = sc22_pivot
sc22_pop['22년 인구 수'] = 82053
sc22_pop.columns = ['업소 수','22년 인구 수']
sc22_pop['매장 커버리지'] = round(sc22_pop['22년 인구 수'] / sc22_pop['업소 수'], 2)
sc22_pop
# Out:
#           업소 수  22년 인구 수  매장 커버리지
# 상권업종대분류명
# 관광/여가/오락   166     82053   494.30
# 부동산        119     82053   689.52
# 생활서비스     1018     82053    80.60
# 소매        2485     82053    33.02
# 숙박         321     82053   255.62
# 스포츠         55     82053  1491.87
# 음식        2900     82053    28.29
# 학문/교육      325     82053   252.47
# 합계        7389     82053    11.10

# %% [markdown]
# #### 소결론
# 1. 매장 커버리지 지수: 인구 수 / 매장 수
# 2. 매장 커버리지 지수의 증가 -> 실질적인 매장 수의 감소를 의미
# 3. 매장 커버리지 지수가 년도가 지남에 따라 (증가,증가) 이거나 (증가, 감소)가 코로나로 인한 피해 규모라고 해석할 수 있지 않을까
# 4. 인구 수를 대입해보았을 때, 절대적인 업소 수의 변동과 큰 차이가 없었음.

# %% [markdown]
# ## 코로나 종합 피해 지수 heatmap

# %%
data = pd.read_csv("/content/drive/MyDrive/8th_EDA/김형민/heatmap.csv")

# %%
df = data.set_index("Unnamed: 0")
del df["스포츠"]

# %%
df.columns = ['T/L','R/E','Serv','Ret','Hous','Food','Edu']

# %%
df.index = ['Seoul', 'GyeongGi', 'GyeongNam', 'GyeongBuk','Busan','Ulsan','Daegu','Gwangju','Jeonnam','Jeonbuk','Daejeon','Sejong','ChungBuk','ChungNam','Jeju','Incheon','Gangwon']

# %%
df
# Out:
#                  T/L        R/E       Serv        Ret       Hous       Food  \
# Seoul      17.317347  -3.647622  -7.354536  -3.296728  14.522880  12.649282
# GyeongGi   -7.818563 -13.489673 -15.197725  -8.350531   0.072500   3.996385
# GyeongNam   5.450850 -10.284017   0.242571  -0.558912   5.919471   9.858468
# GyeongBuk   4.119496  -8.429269   3.655901   0.843964   6.404773   9.832584
# Busan       1.616359 -12.265472   0.186936  -3.438426   7.831357   4.629018
# Ulsan       2.402878  -8.860538   0.307955   1.843125   6.457862  10.788667
# Daegu       4.786658  -9.179397   1.086112  -0.618237  13.511739  11.104018
# Gwangju     8.559164 -11.044562  -1.764297  -0.762514  15.214135  10.413136
# Jeonnam    -1.101922 -19.738914  -0.615257  -2.479285   0.172685   5.328333
# Jeonbuk     7.515401 -11.259846   0.118004   0.800395   1.092078   3.611413
# Daejeon    17.769354 -14.883772   3.478197   5.236508  16.083389  14.485434
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,10))
sns.heatmap(df,linewidths = 0.5, cmap = 'RdBu_r')
plt.title('Covid-19 Damage Rate', fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
